# %% [markdown]
# # VLB LAOS: NLSQ → NUTS
#
# **PNAS Digital Rheometer Twin — large-amplitude oscillatory shear**
#
# ## Learning Objectives
#
# - Fit LAOS stress waveform to extract G₀ and k_d
# - Understand ODE-based LAOS prediction (diffrax)
# - Visualize Lissajous figures from posterior draws
#
# ## Data Source
#
# PNAS 2022 Digital Rheometer Twin dataset (LAOS at ω = 1 rad/s).
#
# ## Estimated Runtime
#
# - Fast demo (1 chain): ~3 min (ODE integration per sample)
# - Full run (4 chains): ~10 min
#
# **Note:** LAOS requires ODE integration via diffrax, making it slower than
# analytical protocols.

# %%
import sys

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    # %pip install -q rheojax openpyxl
    import os
    os.environ["JAX_ENABLE_X64"] = "true"

# %%
# %matplotlib inline
import time
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

from rheojax.core.jax_config import safe_import_jax, verify_float64
from rheojax.models import VLBLocal

jax, jnp = safe_import_jax()
verify_float64()
warnings.filterwarnings('ignore', category=FutureWarning)

# Tutorial utilities
import sys

sys.path.insert(0, str(Path('..').resolve()))
from utils.vlb_tutorial_utils import (
    check_nlsq_fit_quality,
    get_bayesian_config,
    get_output_dir,
    load_pnas_laos,
    plot_trace_and_forest,
    print_convergence,
    print_parameter_table,
    save_figure,
    save_results,
)

print(f"JAX version: {jax.__version__}")
import os
import sys

sys.path.insert(0, os.path.dirname(os.path.abspath("")))
from utils.plotting_utils import (
    display_arviz_diagnostics,
    plot_nlsq_fit,
    plot_posterior_predictive,
)
# Out:
# WARNING:jax._src.xla_bridge:An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# GPU AVAILABLE BUT NOT USED
# ===========================
#   GPU: NVIDIA GeForce RTX 4090 Laptop GPU (SM 8.9)
#   System CUDA: 13.1
#   JAX backend: CPU-only
#
# Enable 20-100x speedup:
#   make install-jax-gpu
#
# Or manually:
#   pip uninstall -y jax jaxlib jax-cuda13-plugin jax-cuda13-pjrt jax-cuda12-plugin jax-cuda12-pjrt
#   pip install "jax[cuda13-local]"
#
# Note: GPU acceleration is supported on Linux only.
# See README.md for details.
#
# JAX version: 0.10.2

# %% [markdown]
# ## 2. Load Experimental Data

# %%
OMEGA = 1.0  # rad/s
STRAIN_IDX = 5  # Medium amplitude

time_data, strain_data, stress_data = load_pnas_laos(
    omega=OMEGA, strain_amplitude_index=STRAIN_IDX, max_points=200
)
GAMMA_0 = float(np.max(np.abs(strain_data)))

print(f'Data points: {len(time_data)}')
print(f'omega = {OMEGA} rad/s')
print(f'gamma_0 = {GAMMA_0:.4f}')
print(f'Time range: {time_data.min():.3f} - {time_data.max():.1f} s')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(time_data, stress_data, 'ko', markersize=2)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Stress [Pa]')
ax1.set_title('LAOS Stress Waveform')
ax1.grid(True, alpha=0.3)

ax2.plot(strain_data, stress_data, 'ko', markersize=2)
ax2.set_xlabel('Strain [-]')
ax2.set_ylabel('Stress [Pa]')
ax2.set_title('Lissajous Figure (data)')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)
# Out:
# /tmp/ipykernel_3079441/3596023134.py:4: UserWarning: PNAS data not found at: /home/wei/Documents/GitHub/rheojax/.claude/worktrees/sharded-hugging-dusk/examples/data/ikh/PNAS_DigitalRheometerTwin_Dataset.xlsx
# Falling back to synthetic Maxwell LAOS data (G0=100 Pa, k_d=2.0 1/s).
#   time_data, strain_data, stress_data = load_pnas_laos(
# [SYNTHETIC] True params: G0=100.0 Pa, k_d=2.0 1/s  (ω=1.0 rad/s, γ₀=0.155)
# Data points: 200
# omega = 1.0 rad/s
# gamma_0 = 0.1547
# Time range: 0.000 - 31.4 s

# %% [markdown]
# ## 3. VLB Forward Model
#
# For LAOS, the VLB distribution tensor ODE is integrated numerically:
#
# $$\dot{\boldsymbol{\mu}} = k_d(\mathbf{I} - \boldsymbol{\mu}) + \mathbf{L}(t) \cdot \boldsymbol{\mu} + \boldsymbol{\mu} \cdot \mathbf{L}^T(t)$$
#
# with $\mathbf{L}(t) = \gamma_0 \omega \cos(\omega t)$.
#
# This uses diffrax (Tsit5 + PID controller) for JAX-compatible ODE integration.
# At small amplitudes, the response is quasi-linear (single harmonic).

# %% [markdown]
# ## 4. Step 1: NLSQ Point Estimation

# %%
model = VLBLocal()

t0 = time.time()
model.fit(time_data, stress_data, test_mode='laos',
          gamma_0=GAMMA_0, omega=OMEGA, method='scipy')
t_nlsq = time.time() - t0

print(f'NLSQ fit time: {t_nlsq:.2f} s')
print(f'G0  = {model.G0:.1f} Pa')
print(f'k_d = {model.k_d:.4f} 1/s')
print(f'eta_0 = {model.G0 / model.k_d:.1f} Pa*s')

# Predict on data grid
stress_pred = model.predict(time_data, test_mode='laos',
                            gamma_0=GAMMA_0, omega=OMEGA)
ss_res = np.sum((stress_data - np.array(stress_pred))**2)
ss_tot = np.sum((stress_data - np.mean(stress_data))**2)
r2 = 1 - ss_res / ss_tot
print(f'R-squared = {r2:.4f}')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(time_data, stress_data, 'ko', markersize=2, label='Data')
ax1.plot(time_data, stress_pred, 'r-', lw=1.5, label='VLB fit')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Stress [Pa]')
ax1.set_title('LAOS Waveform Fit')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Lissajous comparison
ax2.plot(strain_data, stress_data, 'ko', markersize=2, label='Data')
strain_pred = GAMMA_0 * np.sin(OMEGA * time_data)
ax2.plot(strain_pred, stress_pred, 'r-', lw=1.5, label='VLB fit')
ax2.set_xlabel('Strain [-]')
ax2.set_ylabel('Stress [Pa]')
ax2.set_title('Lissajous Comparison')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)
# Out:
# NLSQ fit time: 26.39 s
# G0  = 99.0 Pa
# k_d = 2.1278 1/s
# eta_0 = 46.5 Pa*s
# R-squared = 0.9956

# %% [markdown]
# ## 4. Step 2: Bayesian Inference (NUTS)
#
# LAOS Bayesian inference is slower due to ODE integration at each evaluation.

# %%
check_nlsq_fit_quality(
    model, time_data, stress_data, 'laos',
    noise_sigma=0.03 * np.std(stress_data),
    gamma_0=GAMMA_0, omega=OMEGA,
)

config = get_bayesian_config()
initial_values = {'G0': float(model.G0), 'k_d': float(model.k_d)}
print(f'Config: {config}')
print(f'Warm-start: {initial_values}')

t0 = time.time()
result = model.fit_bayesian(
    time_data, stress_data, test_mode='laos',
    gamma_0=GAMMA_0, omega=OMEGA,
    initial_values=initial_values,
    seed=42,
    **config,
)
t_bayes = time.time() - t0
print(f'\nBayesian inference time: {t_bayes:.1f} s')
# Out:
# ✓  NLSQ fit quality R²=0.9956 ≥ 0.9 — safe to proceed with Bayesian
# ⚠  χ²_red = 4.956 >> 1 — systematic deviations (model–data mismatch or noise underestimated)
# Config: {'num_warmup': 100, 'num_samples': 100, 'num_chains': 1}
# Warm-start: {'G0': 98.99676368377686, 'k_d': 2.1278363976972154}
#   0%|          | 0/200 [00:00<?, ?it/s]
# warmup:   5%|▌         | 10/200 [00:03<01:08,  2.78it/s, 15 steps of size 4.81e-03. acc. prob=0.66]
# warmup:  10%|█         | 20/200 [00:03<00:30,  5.93it/s, 3 steps of size 3.63e-03. acc. prob=0.77]
# warmup:  15%|█▌        | 30/200 [00:04<00:19,  8.78it/s, 31 steps of size 1.78e-03. acc. prob=0.79]
# warmup:  20%|██        | 40/200 [00:05<00:15, 10.53it/s, 71 steps of size 2.60e-03. acc. prob=0.82]
# warmup:  25%|██▌       | 50/200 [00:05<00:11, 12.53it/s, 3 steps of size 5.00e-04. acc. prob=0.82]
# warmup:  30%|███       | 60/200 [00:06<00:10, 12.91it/s, 15 steps of size 2.21e-03. acc. prob=0.84]
# warmup:  35%|███▌      | 70/200 [00:06<00:07, 16.95it/s, 7 steps of size 1.22e-03. acc. prob=0.84]
# warmup:  40%|████      | 80/200 [00:06<00:05, 20.27it/s, 31 steps of size 8.77e-04. acc. prob=0.84]
# warmup:  45%|████▌     | 90/200 [00:07<00:07, 14.53it/s, 15 steps of size 3.05e-03. acc. prob=0.85]
# warmup:  50%|█████     | 100/200 [00:08<00:06, 15.04it/s, 3 steps of size 1.54e-01. acc. prob=0.86]
# sample:  55%|█████▌    | 110/200 [00:08<00:04, 19.48it/s, 11 steps of size 1.54e-01. acc. prob=0.94]
# sample:  60%|██████    | 120/200 [00:08<00:03, 24.22it/s, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  65%|██████▌   | 130/200 [00:09<00:02, 29.06it/s, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  70%|███████   | 140/200 [00:09<00:01, 34.13it/s, 11 steps of size 1.54e-01. acc. prob=0.93]
# sample:  75%|███████▌  | 150/200 [00:09<00:01, 38.73it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  80%|████████  | 160/200 [00:09<00:00, 45.77it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  85%|████████▌ | 170/200 [00:09<00:00, 47.10it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  90%|█████████ | 180/200 [00:09<00:00, 54.28it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  95%|█████████▌| 190/200 [00:10<00:00, 59.23it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample: 100%|██████████| 200/200 [00:10<00:00, 58.76it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample: 100%|██████████| 200/200 [00:10<00:00, 19.57it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# Bayesian inference time: 18.2 s

# %% [markdown]
# ## 5. Convergence Diagnostics

# %%
param_names = ["G0", "k_d"]
converged = print_convergence(result, param_names)
# Out:
# Convergence Diagnostics
# ==================================================
#  Parameter     R-hat       ESS
# --------------------------------------------------
#         G0    0.9932        40 *
#        k_d    0.9901        36 *
#
# Divergences: 0
# Convergence: CHECK REQUIRED
#
# Note: FAST_MODE uses 1 chain (100 samples). R-hat is a split-chain
#       estimate — less reliable than multi-chain. Thresholds relaxed to
#       R-hat < 1.1, ESS > 40. Use FAST_MODE=False for
#       publication-quality diagnostics (4 chains, 1000 samples).

# %%
display_arviz_diagnostics(result, param_names, fast_mode=os.environ.get("FAST_MODE", "1") == "1")

# %% [markdown]
# ## 6. Posterior Summary

# %%
posterior = result.posterior_samples
nlsq_vals = {"G0": model.G0, "k_d": model.k_d}
print_parameter_table(["G0", "k_d"], nlsq_vals, posterior)
# Out:
# Parameter Comparison
# ==========================================================
#    Param        NLSQ  Bayes (median)                95% CI
# ----------------------------------------------------------
#       G0          99           100.5  [99.66, 101.1]
#      k_d       2.128           2.016  [2, 2.033]

# %% [markdown]
# ### Bayesian Fit Quality Check
#
# The NLSQ warm-start can land in a local minimum for ODE-based models — the LAOS
# loss landscape is non-convex. χ²_red > 1 for the NLSQ prediction is expected and
# informative: it flags that the warm-start is suboptimal, **not** that the model
# is wrong. The Bayesian posterior median is the reliable best-fit estimate, and
# its χ²_red should be close to 1.0.

# %%
posterior = result.posterior_samples
model_bayes = VLBLocal()
model_bayes.parameters.set_value('G0', float(np.median(posterior['G0'])))
model_bayes.parameters.set_value('k_d', float(np.median(posterior['k_d'])))
print(f"Posterior median: G0={model_bayes.G0:.2f} Pa, k_d={model_bayes.k_d:.4f} 1/s")
print("Bayesian median fit quality:")
check_nlsq_fit_quality(
    model_bayes, time_data, stress_data, 'laos',
    noise_sigma=0.03 * np.std(stress_data),
    gamma_0=GAMMA_0, omega=OMEGA,
)
# Out:
# Posterior median: G0=100.46 Pa, k_d=2.0165 1/s
# Bayesian median fit quality:
# ✓  NLSQ fit quality R²=0.9991 ≥ 0.9 — safe to proceed with Bayesian
# ✓  χ²_red = 0.972 ≈ 1.0 — fit consistent with σ=0.144 (absolute) noise
# 0.9991337180755707

# %% [markdown]
# ## 7. Posterior Predictive Check

# %%
posterior = result.posterior_samples
n_draws = min(50, len(posterior['G0']))  # Fewer draws (ODE is slow)

stress_samples = []
for i in range(n_draws):
    model.parameters.set_value('G0', float(posterior['G0'][i]))
    model.parameters.set_value('k_d', float(posterior['k_d'][i]))
    stress_samples.append(np.array(
        model.predict(time_data, test_mode='laos',
                      gamma_0=GAMMA_0, omega=OMEGA)
    ))

stress_arr = np.array(stress_samples)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Waveform PPC
ax1.fill_between(time_data,
    np.percentile(stress_arr, 2.5, axis=0),
    np.percentile(stress_arr, 97.5, axis=0),
    alpha=0.3, color='C0', label='95% CI')
ax1.plot(time_data, np.median(stress_arr, axis=0),
         'C0-', lw=1.5, label='Posterior median')
ax1.plot(time_data, stress_data, 'ko', markersize=2, label='Data')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Stress [Pa]')
ax1.set_title('Waveform PPC')
ax1.legend(fontsize=9)
ax1.grid(True, alpha=0.3)

# Lissajous PPC (overlay several draws)
for i in range(min(10, n_draws)):
    strain_i = GAMMA_0 * np.sin(OMEGA * time_data)
    ax2.plot(strain_i, stress_samples[i], '-', color='C0', alpha=0.15, lw=0.8)
ax2.plot(strain_data, stress_data, 'ko', markersize=2, label='Data')
ax2.set_xlabel('Strain [-]')
ax2.set_ylabel('Stress [Pa]')
ax2.set_title('Lissajous PPC')
ax2.legend(fontsize=9)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)

# %% [markdown]
# ## 8. Save Results

# %%
output_dir = get_output_dir("laos")
save_results(output_dir, model, result, ["G0", "k_d"], {"gamma_0": GAMMA_0, "omega": OMEGA})
print("Done.")
# Out:
# Saved to /home/wei/Documents/GitHub/rheojax/.claude/worktrees/sharded-hugging-dusk/examples/utils/../outputs/vlb/laos/
# Done.

# %% [markdown]
# ## Key Takeaways
#
# 1. **LAOS requires ODE integration** — slower than analytical protocols
# 2. **VLB predicts near-elliptical Lissajous** at moderate amplitudes
# 3. **Bayesian inference works** but is computationally heavier
# 4. **Nonlinear LAOS features** (distorted Lissajous) require
#    Bell or FENE extensions to VLB
# 5. **NLSQ χ²_red > 1 is expected for LAOS** — ODE-based loss landscapes are
#    non-convex and NLSQ can find local minima. R² > 0.99 confirms a plausible
#    warm-start, but χ²_red may be > 1 if k_d is slightly off. NUTS explores
#    the full posterior and recovers the true parameters; use the **Bayesian
#    median χ²_red** as the definitive fit-quality diagnostic.
#
# ## Series Summary
#
# | Protocol | Parameters Identified | Analytical? |
# |-|-|-|
# | Flow curve | η₀ = G₀/k_d only | Yes |
# | Creep | G₀ and k_d | Yes |
# | Relaxation | G₀ and k_d | Yes |
# | Startup | G₀ and k_d | Yes |
# | **SAOS** | **G₀ and k_d (best)** | **Yes** |
# | LAOS | G₀ and k_d | No (ODE) |
