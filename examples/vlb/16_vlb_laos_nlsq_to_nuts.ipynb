# %% [markdown]
# # VLB LAOS: NLSQ → NUTS
#
# **PNAS Digital Rheometer Twin — large-amplitude oscillatory shear**
#
# ## Learning Objectives
#
# - Fit LAOS stress waveform to extract G₀ and k_d
# - Understand ODE-based LAOS prediction (diffrax)
# - Visualize Lissajous figures from posterior draws
#
# ## Data Source
#
# PNAS 2022 Digital Rheometer Twin dataset (LAOS at ω = 1 rad/s).
#
# ## Estimated Runtime
#
# - Fast demo (1 chain): ~3 min (ODE integration per sample)
# - Full run (4 chains): ~10 min
#
# **Note:** LAOS requires ODE integration via diffrax, making it slower than
# analytical protocols.

# %%
import sys

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    # %pip install -q rheojax openpyxl
    import os
    os.environ["JAX_ENABLE_X64"] = "true"

# %%
# %matplotlib inline
import time
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

from rheojax.core.jax_config import safe_import_jax, verify_float64
from rheojax.models import VLBLocal

jax, jnp = safe_import_jax()
verify_float64()
warnings.filterwarnings('ignore', category=FutureWarning)

# Tutorial utilities
import sys

sys.path.insert(0, str(Path('..').resolve()))
from utils.vlb_tutorial_utils import (
    check_nlsq_fit_quality,
    get_bayesian_config,
    get_output_dir,
    load_pnas_laos,
    plot_trace_and_forest,
    print_convergence,
    print_parameter_table,
    save_figure,
    save_results,
)

print(f"JAX version: {jax.__version__}")
import os
import sys

sys.path.insert(0, os.path.dirname(os.path.abspath("")))
from utils.plotting_utils import (
    display_arviz_diagnostics,
    plot_nlsq_fit,
    plot_posterior_predictive,
)
# Out:
# JAX version: 0.10.1

# %% [markdown]
# ## 2. Load Experimental Data

# %%
OMEGA = 1.0  # rad/s
STRAIN_IDX = 5  # Medium amplitude

time_data, strain_data, stress_data = load_pnas_laos(
    omega=OMEGA, strain_amplitude_index=STRAIN_IDX, max_points=200
)
GAMMA_0 = float(np.max(np.abs(strain_data)))

print(f'Data points: {len(time_data)}')
print(f'omega = {OMEGA} rad/s')
print(f'gamma_0 = {GAMMA_0:.4f}')
print(f'Time range: {time_data.min():.3f} - {time_data.max():.1f} s')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(time_data, stress_data, 'ko', markersize=2)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Stress [Pa]')
ax1.set_title('LAOS Stress Waveform')
ax1.grid(True, alpha=0.3)

ax2.plot(strain_data, stress_data, 'ko', markersize=2)
ax2.set_xlabel('Strain [-]')
ax2.set_ylabel('Stress [Pa]')
ax2.set_title('Lissajous Figure (data)')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)
# Out:
# /tmp/ipykernel_1723521/3596023134.py:4: UserWarning: PNAS data not found at: /home/wei/Documents/GitHub/rheojax/examples/data/ikh/PNAS_DigitalRheometerTwin_Dataset.xlsx
# Falling back to synthetic Maxwell LAOS data (G0=100 Pa, k_d=2.0 1/s).
#   time_data, strain_data, stress_data = load_pnas_laos(
# [SYNTHETIC] True params: G0=100.0 Pa, k_d=2.0 1/s  (ω=1.0 rad/s, γ₀=0.155)
# Data points: 200
# omega = 1.0 rad/s
# gamma_0 = 0.1547
# Time range: 0.000 - 31.4 s

# %% [markdown]
# ## 3. VLB Forward Model
#
# For LAOS, the VLB distribution tensor ODE is integrated numerically:
#
# $$\dot{\boldsymbol{\mu}} = k_d(\mathbf{I} - \boldsymbol{\mu}) + \mathbf{L}(t) \cdot \boldsymbol{\mu} + \boldsymbol{\mu} \cdot \mathbf{L}^T(t)$$
#
# with $\mathbf{L}(t) = \gamma_0 \omega \cos(\omega t)$.
#
# This uses diffrax (Tsit5 + PID controller) for JAX-compatible ODE integration.
# At small amplitudes, the response is quasi-linear (single harmonic).

# %% [markdown]
# ## 4. Step 1: NLSQ Point Estimation

# %%
model = VLBLocal()

t0 = time.time()
model.fit(time_data, stress_data, test_mode='laos',
          gamma_0=GAMMA_0, omega=OMEGA, method='scipy')
t_nlsq = time.time() - t0

print(f'NLSQ fit time: {t_nlsq:.2f} s')
print(f'G0  = {model.G0:.1f} Pa')
print(f'k_d = {model.k_d:.4f} 1/s')
print(f'eta_0 = {model.G0 / model.k_d:.1f} Pa*s')

# Predict on data grid
stress_pred = model.predict(time_data, test_mode='laos',
                            gamma_0=GAMMA_0, omega=OMEGA)
ss_res = np.sum((stress_data - np.array(stress_pred))**2)
ss_tot = np.sum((stress_data - np.mean(stress_data))**2)
r2 = 1 - ss_res / ss_tot
print(f'R-squared = {r2:.4f}')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(time_data, stress_data, 'ko', markersize=2, label='Data')
ax1.plot(time_data, stress_pred, 'r-', lw=1.5, label='VLB fit')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Stress [Pa]')
ax1.set_title('LAOS Waveform Fit')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Lissajous comparison
ax2.plot(strain_data, stress_data, 'ko', markersize=2, label='Data')
strain_pred = GAMMA_0 * np.sin(OMEGA * time_data)
ax2.plot(strain_pred, stress_pred, 'r-', lw=1.5, label='VLB fit')
ax2.set_xlabel('Strain [-]')
ax2.set_ylabel('Stress [Pa]')
ax2.set_title('Lissajous Comparison')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)
# Out:
# NLSQ fit time: 83.92 s
# G0  = 99.0 Pa
# k_d = 2.1278 1/s
# eta_0 = 46.5 Pa*s
# R-squared = 0.9956

# %% [markdown]
# ## 4. Step 2: Bayesian Inference (NUTS)
#
# LAOS Bayesian inference is slower due to ODE integration at each evaluation.

# %%
check_nlsq_fit_quality(
    model, time_data, stress_data, 'laos',
    noise_sigma=0.03 * np.std(stress_data),
    gamma_0=GAMMA_0, omega=OMEGA,
)

config = get_bayesian_config()
initial_values = {'G0': float(model.G0), 'k_d': float(model.k_d)}
print(f'Config: {config}')
print(f'Warm-start: {initial_values}')

t0 = time.time()
result = model.fit_bayesian(
    time_data, stress_data, test_mode='laos',
    gamma_0=GAMMA_0, omega=OMEGA,
    initial_values=initial_values,
    seed=42,
    **config,
)
t_bayes = time.time() - t0
print(f'\nBayesian inference time: {t_bayes:.1f} s')
# Out:
# ✓  NLSQ fit quality R²=0.9956 ≥ 0.9 — safe to proceed with Bayesian
# ⚠  χ²_red = 4.956 >> 1 — systematic deviations (model–data mismatch or noise underestimated)
# Config: {'num_warmup': 100, 'num_samples': 100, 'num_chains': 1}
# Warm-start: {'G0': 98.99676368377513, 'k_d': 2.127836397697059}
#   0%|          | 0/200 [00:00<?, ?it/s]
# warmup:   5%|▌         | 10/200 [00:16<05:05,  1.61s/it, 15 steps of size 4.81e-03. acc. prob=0.66]
# warmup:   5%|▌         | 10/200 [00:29<05:05,  1.61s/it, 15 steps of size 5.73e-03. acc. prob=0.74]
# warmup:   8%|▊         | 16/200 [00:31<06:16,  2.05s/it, 12 steps of size 9.28e-04. acc. prob=0.71]
# warmup:   8%|▊         | 17/200 [00:35<06:51,  2.25s/it, 31 steps of size 1.34e-03. acc. prob=0.73]
# warmup:   9%|▉         | 18/200 [00:36<06:19,  2.08s/it, 7 steps of size 1.89e-03. acc. prob=0.74]
# warmup:  10%|▉         | 19/200 [00:38<06:10,  2.05s/it, 15 steps of size 2.58e-03. acc. prob=0.76]
# warmup:  10%|█         | 20/200 [00:38<05:14,  1.75s/it, 3 steps of size 3.63e-03. acc. prob=0.77]
# warmup:  10%|█         | 21/200 [00:42<06:15,  2.10s/it, 31 steps of size 5.09e-03. acc. prob=0.78]
# warmup:  11%|█         | 22/200 [00:42<05:21,  1.81s/it, 7 steps of size 5.38e-03. acc. prob=0.78]
# warmup:  12%|█▏        | 23/200 [00:43<04:25,  1.50s/it, 4 steps of size 4.44e-04. acc. prob=0.75]
# warmup:  12%|█▏        | 24/200 [00:51<09:08,  3.12s/it, 63 steps of size 6.46e-04. acc. prob=0.76]
# warmup:  12%|█▎        | 25/200 [00:59<12:58,  4.45s/it, 63 steps of size 9.31e-04. acc. prob=0.77]
# warmup:  13%|█▎        | 26/200 [01:00<09:58,  3.44s/it, 7 steps of size 1.24e-03. acc. prob=0.78]
# warmup:  14%|█▎        | 27/200 [01:03<09:57,  3.45s/it, 31 steps of size 1.78e-03. acc. prob=0.79]
# warmup:  14%|█▍        | 28/200 [01:04<07:44,  2.70s/it, 7 steps of size 2.38e-03. acc. prob=0.79]
# warmup:  14%|█▍        | 29/200 [01:06<07:01,  2.47s/it, 15 steps of size 1.26e-03. acc. prob=0.79]
# warmup:  15%|█▌        | 30/200 [01:10<08:12,  2.89s/it, 31 steps of size 1.78e-03. acc. prob=0.79]
# warmup:  16%|█▌        | 31/200 [01:13<08:49,  3.13s/it, 31 steps of size 2.50e-03. acc. prob=0.80]
# warmup:  16%|█▌        | 32/200 [01:15<07:20,  2.62s/it, 11 steps of size 3.48e-03. acc. prob=0.81]
# warmup:  16%|█▋        | 33/200 [01:17<06:42,  2.41s/it, 15 steps of size 1.06e-03. acc. prob=0.80]
# warmup:  17%|█▋        | 34/200 [01:19<06:39,  2.41s/it, 19 steps of size 1.27e-03. acc. prob=0.80]
# warmup:  18%|█▊        | 35/200 [01:20<04:58,  1.81s/it, 3 steps of size 1.77e-03. acc. prob=0.81]
# warmup:  18%|█▊        | 36/200 [01:20<03:47,  1.39s/it, 3 steps of size 9.20e-04. acc. prob=0.80]
# warmup:  18%|█▊        | 37/200 [01:29<10:08,  3.74s/it, 79 steps of size 1.28e-03. acc. prob=0.81]
# warmup:  19%|█▉        | 38/200 [01:38<14:25,  5.34s/it, 75 steps of size 1.75e-03. acc. prob=0.81]
# warmup:  20%|█▉        | 39/200 [01:44<14:41,  5.47s/it, 47 steps of size 1.91e-03. acc. prob=0.81]
# warmup:  20%|██        | 40/200 [01:52<16:49,  6.31s/it, 71 steps of size 2.60e-03. acc. prob=0.82]
# warmup:  20%|██        | 41/200 [01:58<16:16,  6.14s/it, 47 steps of size 1.97e-03. acc. prob=0.82]
# warmup:  21%|██        | 42/200 [02:04<16:16,  6.18s/it, 47 steps of size 2.68e-03. acc. prob=0.82]
# warmup:  22%|██▏       | 43/200 [02:10<15:39,  5.98s/it, 49 steps of size 1.32e-03. acc. prob=0.82]
# warmup:  22%|██▏       | 44/200 [02:22<19:56,  7.67s/it, 95 steps of size 1.80e-03. acc. prob=0.82]
# warmup:  22%|██▎       | 45/200 [02:24<15:28,  5.99s/it, 15 steps of size 2.28e-03. acc. prob=0.82]
# warmup:  23%|██▎       | 46/200 [02:27<13:35,  5.30s/it, 27 steps of size 2.19e-03. acc. prob=0.82]
# warmup:  24%|██▎       | 47/200 [02:28<09:43,  3.82s/it, 3 steps of size 1.64e-03. acc. prob=0.82]
# warmup:  24%|██▍       | 48/200 [02:28<07:02,  2.78s/it, 3 steps of size 2.20e-03. acc. prob=0.83]
# warmup:  24%|██▍       | 49/200 [02:32<08:10,  3.25s/it, 39 steps of size 2.69e-03. acc. prob=0.83]
# warmup:  25%|██▌       | 50/200 [02:33<05:59,  2.39s/it, 3 steps of size 5.00e-04. acc. prob=0.82]
# warmup:  26%|██▌       | 51/200 [03:00<24:13,  9.75s/it, 223 steps of size 6.60e-04. acc. prob=0.82]
# warmup:  26%|██▌       | 52/200 [03:01<17:30,  7.10s/it, 7 steps of size 8.24e-04. acc. prob=0.82]
# warmup:  26%|██▋       | 53/200 [03:13<21:04,  8.60s/it, 95 steps of size 1.10e-03. acc. prob=0.83]
# warmup:  27%|██▋       | 54/200 [03:14<15:14,  6.27s/it, 7 steps of size 1.15e-03. acc. prob=0.83]
# warmup:  28%|██▊       | 55/200 [03:16<12:31,  5.18s/it, 23 steps of size 1.51e-03. acc. prob=0.83]
# warmup:  28%|██▊       | 56/200 [03:17<09:21,  3.90s/it, 7 steps of size 1.34e-03. acc. prob=0.83]
# warmup:  28%|██▊       | 57/200 [03:19<07:52,  3.30s/it, 15 steps of size 1.77e-03. acc. prob=0.83]
# warmup:  29%|██▉       | 58/200 [03:21<06:49,  2.89s/it, 15 steps of size 2.29e-03. acc. prob=0.84]
# warmup:  30%|██▉       | 59/200 [03:29<10:28,  4.45s/it, 63 steps of size 2.16e-03. acc. prob=0.84]
# warmup:  30%|███       | 60/200 [03:31<08:56,  3.83s/it, 15 steps of size 2.21e-03. acc. prob=0.84]
# warmup:  30%|███       | 61/200 [03:34<08:05,  3.49s/it, 23 steps of size 2.83e-03. acc. prob=0.84]
# warmup:  31%|███       | 62/200 [03:35<06:10,  2.69s/it, 7 steps of size 2.62e-03. acc. prob=0.84]
# warmup:  32%|███▏      | 63/200 [03:35<04:32,  1.99s/it, 3 steps of size 1.59e-03. acc. prob=0.84]
# warmup:  32%|███▏      | 64/200 [03:37<04:38,  2.05s/it, 19 steps of size 2.05e-03. acc. prob=0.84]
# warmup:  32%|███▎      | 65/200 [03:40<05:13,  2.32s/it, 23 steps of size 1.95e-03. acc. prob=0.84]
# warmup:  33%|███▎      | 66/200 [03:41<04:15,  1.91s/it, 7 steps of size 2.41e-03. acc. prob=0.84]
# warmup:  34%|███▎      | 67/200 [03:43<03:51,  1.74s/it, 11 steps of size 2.45e-03. acc. prob=0.84]
# warmup:  34%|███▍      | 68/200 [03:43<03:12,  1.46s/it, 7 steps of size 3.00e-03. acc. prob=0.84]
# warmup:  34%|███▍      | 69/200 [03:46<03:54,  1.79s/it, 19 steps of size 3.14e-03. acc. prob=0.84]
# warmup:  35%|███▌      | 70/200 [03:47<03:18,  1.52s/it, 7 steps of size 1.22e-03. acc. prob=0.84]
# warmup:  36%|███▌      | 71/200 [03:49<03:43,  1.73s/it, 15 steps of size 1.41e-03. acc. prob=0.84]
# warmup:  36%|███▌      | 72/200 [03:52<04:18,  2.02s/it, 19 steps of size 1.79e-03. acc. prob=0.84]
# warmup:  36%|███▋      | 73/200 [03:54<04:12,  1.99s/it, 15 steps of size 2.24e-03. acc. prob=0.84]
# warmup:  37%|███▋      | 74/200 [03:55<03:25,  1.63s/it, 7 steps of size 2.87e-03. acc. prob=0.85]
# warmup:  38%|███▊      | 75/200 [03:55<02:36,  1.25s/it, 3 steps of size 2.84e-03. acc. prob=0.85]
# warmup:  38%|███▊      | 76/200 [03:56<02:19,  1.13s/it, 7 steps of size 2.82e-03. acc. prob=0.85]
# warmup:  38%|███▊      | 77/200 [04:01<05:06,  2.49s/it, 47 steps of size 2.81e-03. acc. prob=0.85]
# warmup:  39%|███▉      | 78/200 [04:02<04:07,  2.03s/it, 7 steps of size 2.70e-03. acc. prob=0.85]
# warmup:  40%|███▉      | 79/200 [04:04<03:59,  1.98s/it, 15 steps of size 7.03e-04. acc. prob=0.84]
# warmup:  40%|████      | 80/200 [04:08<04:56,  2.47s/it, 31 steps of size 8.77e-04. acc. prob=0.84]
# warmup:  40%|████      | 81/200 [04:25<13:54,  7.01s/it, 143 steps of size 1.12e-03. acc. prob=0.84]
# warmup:  41%|████      | 82/200 [04:34<14:44,  7.50s/it, 71 steps of size 1.42e-03. acc. prob=0.85]
# warmup:  42%|████▏     | 83/200 [04:37<11:37,  5.97s/it, 15 steps of size 1.80e-03. acc. prob=0.85]
# warmup:  42%|████▏     | 84/200 [04:38<08:56,  4.63s/it, 11 steps of size 1.03e-03. acc. prob=0.84]
# warmup:  42%|████▎     | 85/200 [04:53<14:57,  7.81s/it, 127 steps of size 1.30e-03. acc. prob=0.85]
# warmup:  43%|████▎     | 86/200 [05:05<16:59,  8.94s/it, 91 steps of size 1.62e-03. acc. prob=0.85]
# warmup:  44%|████▎     | 87/200 [05:14<17:11,  9.13s/it, 79 steps of size 2.02e-03. acc. prob=0.85]
# warmup:  44%|████▍     | 88/200 [05:15<12:24,  6.65s/it, 7 steps of size 2.52e-03. acc. prob=0.85]
# warmup:  44%|████▍     | 89/200 [05:18<09:56,  5.38s/it, 15 steps of size 2.57e-03. acc. prob=0.85]
# warmup:  45%|████▌     | 90/200 [05:20<07:57,  4.34s/it, 15 steps of size 3.04e-03. acc. prob=0.85]
# warmup:  46%|████▌     | 91/200 [05:50<22:17, 12.27s/it, 255 steps of size 3.65e-02. acc. prob=0.85]
# warmup:  46%|████▌     | 92/200 [05:54<17:33,  9.75s/it, 31 steps of size 4.85e-02. acc. prob=0.86]
# warmup:  46%|████▋     | 93/200 [05:57<13:37,  7.64s/it, 23 steps of size 6.72e-02. acc. prob=0.86]
# warmup:  47%|████▋     | 94/200 [05:58<09:53,  5.60s/it, 7 steps of size 8.80e-02. acc. prob=0.86]
# warmup:  48%|████▊     | 95/200 [06:02<08:54,  5.09s/it, 31 steps of size 1.02e-01. acc. prob=0.86]
# warmup:  48%|████▊     | 96/200 [06:02<06:23,  3.69s/it, 3 steps of size 1.42e-01. acc. prob=0.86]
# warmup:  48%|████▊     | 97/200 [06:04<05:31,  3.22s/it, 15 steps of size 1.80e-01. acc. prob=0.86]
# warmup:  49%|████▉     | 98/200 [06:05<04:01,  2.37s/it, 3 steps of size 2.51e-01. acc. prob=0.86]
# warmup:  50%|████▉     | 99/200 [06:05<03:13,  1.92s/it, 7 steps of size 2.08e-01. acc. prob=0.86]
# warmup:  50%|█████     | 100/200 [06:06<02:25,  1.45s/it, 3 steps of size 1.54e-01. acc. prob=0.86]
# sample:  50%|█████     | 101/200 [06:06<01:44,  1.06s/it, 1 steps of size 1.54e-01. acc. prob=0.93]
# sample:  51%|█████     | 102/200 [06:07<01:35,  1.02it/s, 7 steps of size 1.54e-01. acc. prob=0.96]
# sample:  52%|█████▏    | 103/200 [06:08<01:29,  1.09it/s, 7 steps of size 1.54e-01. acc. prob=0.97]
# sample:  52%|█████▏    | 104/200 [06:09<01:50,  1.15s/it, 15 steps of size 1.54e-01. acc. prob=0.94]
# sample:  52%|█████▎    | 105/200 [06:10<01:39,  1.05s/it, 7 steps of size 1.54e-01. acc. prob=0.95]
# sample:  53%|█████▎    | 106/200 [06:10<01:12,  1.29it/s, 1 steps of size 1.54e-01. acc. prob=0.96]
# sample:  54%|█████▎    | 107/200 [06:11<01:00,  1.54it/s, 3 steps of size 1.54e-01. acc. prob=0.96]
# sample:  54%|█████▍    | 108/200 [06:12<01:19,  1.15it/s, 11 steps of size 1.54e-01. acc. prob=0.95]
# sample:  55%|█████▍    | 109/200 [06:13<01:19,  1.14it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  55%|█████▌    | 110/200 [06:14<01:33,  1.04s/it, 11 steps of size 1.54e-01. acc. prob=0.94]
# sample:  56%|█████▌    | 111/200 [06:15<01:16,  1.16it/s, 3 steps of size 1.54e-01. acc. prob=0.92]
# sample:  56%|█████▌    | 112/200 [06:16<01:28,  1.01s/it, 11 steps of size 1.54e-01. acc. prob=0.93]
# sample:  56%|█████▋    | 113/200 [06:16<01:11,  1.22it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  57%|█████▋    | 114/200 [06:18<01:24,  1.02it/s, 11 steps of size 1.54e-01. acc. prob=0.91]
# sample:  57%|█████▊    | 115/200 [06:19<01:22,  1.03it/s, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  58%|█████▊    | 116/200 [06:19<01:06,  1.26it/s, 3 steps of size 1.54e-01. acc. prob=0.91]
# sample:  58%|█████▊    | 117/200 [06:20<01:10,  1.18it/s, 7 steps of size 1.54e-01. acc. prob=0.91]
# sample:  59%|█████▉    | 118/200 [06:21<01:11,  1.14it/s, 7 steps of size 1.54e-01. acc. prob=0.91]
# sample:  60%|█████▉    | 119/200 [06:23<01:47,  1.32s/it, 15 steps of size 1.54e-01. acc. prob=0.91]
# sample:  60%|██████    | 120/200 [06:24<01:39,  1.24s/it, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  60%|██████    | 121/200 [06:26<01:46,  1.34s/it, 11 steps of size 1.54e-01. acc. prob=0.92]
# sample:  61%|██████    | 122/200 [06:26<01:17,  1.01it/s, 1 steps of size 1.54e-01. acc. prob=0.92]
# sample:  62%|██████▏   | 123/200 [06:26<00:57,  1.35it/s, 1 steps of size 1.54e-01. acc. prob=0.92]
# sample:  62%|██████▏   | 124/200 [06:28<01:18,  1.03s/it, 15 steps of size 1.54e-01. acc. prob=0.92]
# sample:  62%|██████▎   | 125/200 [06:29<01:11,  1.05it/s, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  63%|██████▎   | 126/200 [06:31<01:27,  1.18s/it, 15 steps of size 1.54e-01. acc. prob=0.92]
# sample:  64%|██████▎   | 127/200 [06:31<01:17,  1.07s/it, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  64%|██████▍   | 128/200 [06:33<01:32,  1.29s/it, 15 steps of size 1.54e-01. acc. prob=0.93]
# sample:  64%|██████▍   | 129/200 [06:35<01:44,  1.48s/it, 15 steps of size 1.54e-01. acc. prob=0.92]
# sample:  65%|██████▌   | 130/200 [06:36<01:32,  1.31s/it, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  66%|██████▌   | 131/200 [06:36<01:12,  1.05s/it, 3 steps of size 1.54e-01. acc. prob=0.92]
# sample:  66%|██████▌   | 132/200 [06:38<01:16,  1.12s/it, 11 steps of size 1.54e-01. acc. prob=0.92]
# sample:  66%|██████▋   | 133/200 [06:39<01:09,  1.04s/it, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  67%|██████▋   | 134/200 [06:39<00:55,  1.18it/s, 3 steps of size 1.54e-01. acc. prob=0.92]
# sample:  68%|██████▊   | 135/200 [06:40<00:59,  1.10it/s, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  68%|██████▊   | 136/200 [06:41<01:00,  1.06it/s, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  68%|██████▊   | 137/200 [06:43<01:27,  1.39s/it, 15 steps of size 1.54e-01. acc. prob=0.92]
# sample:  69%|██████▉   | 138/200 [06:45<01:21,  1.32s/it, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  70%|██████▉   | 139/200 [06:46<01:22,  1.35s/it, 11 steps of size 1.54e-01. acc. prob=0.93]
# sample:  70%|███████   | 140/200 [06:47<01:21,  1.36s/it, 11 steps of size 1.54e-01. acc. prob=0.93]
# sample:  70%|███████   | 141/200 [06:48<01:03,  1.08s/it, 3 steps of size 1.54e-01. acc. prob=0.92]
# sample:  71%|███████   | 142/200 [06:48<00:50,  1.15it/s, 3 steps of size 1.54e-01. acc. prob=0.92]
# sample:  72%|███████▏  | 143/200 [06:49<00:40,  1.40it/s, 3 steps of size 1.54e-01. acc. prob=0.92]
# sample:  72%|███████▏  | 144/200 [06:50<00:48,  1.17it/s, 11 steps of size 1.54e-01. acc. prob=0.93]
# sample:  72%|███████▎  | 145/200 [06:51<00:46,  1.19it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  73%|███████▎  | 146/200 [06:52<00:59,  1.09s/it, 15 steps of size 1.54e-01. acc. prob=0.93]
# sample:  74%|███████▎  | 147/200 [06:54<01:09,  1.31s/it, 15 steps of size 1.54e-01. acc. prob=0.93]
# sample:  74%|███████▍  | 148/200 [06:55<01:02,  1.19s/it, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  74%|███████▍  | 149/200 [06:56<00:56,  1.11s/it, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  75%|███████▌  | 150/200 [06:57<00:52,  1.06s/it, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  76%|███████▌  | 151/200 [06:58<00:56,  1.15s/it, 11 steps of size 1.54e-01. acc. prob=0.93]
# sample:  76%|███████▌  | 152/200 [06:59<00:50,  1.05s/it, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  76%|███████▋  | 153/200 [07:00<00:46,  1.00it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  77%|███████▋  | 154/200 [07:01<00:44,  1.03it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  78%|███████▊  | 155/200 [07:01<00:35,  1.26it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  78%|███████▊  | 156/200 [07:02<00:36,  1.22it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  78%|███████▊  | 157/200 [07:02<00:29,  1.44it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  79%|███████▉  | 158/200 [07:03<00:25,  1.64it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  80%|███████▉  | 159/200 [07:05<00:40,  1.01it/s, 15 steps of size 1.54e-01. acc. prob=0.93]
# sample:  80%|████████  | 160/200 [07:06<00:38,  1.04it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  80%|████████  | 161/200 [07:08<00:53,  1.37s/it, 15 steps of size 1.54e-01. acc. prob=0.92]
# sample:  81%|████████  | 162/200 [07:10<00:56,  1.50s/it, 15 steps of size 1.54e-01. acc. prob=0.92]
# sample:  82%|████████▏ | 163/200 [07:11<00:57,  1.54s/it, 15 steps of size 1.54e-01. acc. prob=0.92]
# sample:  82%|████████▏ | 164/200 [07:12<00:47,  1.32s/it, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  82%|████████▎ | 165/200 [07:13<00:36,  1.04s/it, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  83%|████████▎ | 166/200 [07:13<00:28,  1.19it/s, 3 steps of size 1.54e-01. acc. prob=0.92]
# sample:  84%|████████▎ | 167/200 [07:14<00:27,  1.21it/s, 7 steps of size 1.54e-01. acc. prob=0.92]
# sample:  84%|████████▍ | 168/200 [07:18<00:55,  1.73s/it, 31 steps of size 1.54e-01. acc. prob=0.93]
# sample:  84%|████████▍ | 169/200 [07:20<00:55,  1.78s/it, 15 steps of size 1.54e-01. acc. prob=0.93]
# sample:  85%|████████▌ | 170/200 [07:20<00:44,  1.49s/it, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  86%|████████▌ | 171/200 [07:21<00:33,  1.16s/it, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  86%|████████▌ | 172/200 [07:22<00:29,  1.06s/it, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  86%|████████▋ | 173/200 [07:22<00:23,  1.15it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  87%|████████▋ | 174/200 [07:24<00:30,  1.15s/it, 15 steps of size 1.54e-01. acc. prob=0.93]
# sample:  88%|████████▊ | 175/200 [07:24<00:23,  1.07it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  88%|████████▊ | 176/200 [07:25<00:22,  1.07it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  88%|████████▊ | 177/200 [07:26<00:19,  1.17it/s, 5 steps of size 1.54e-01. acc. prob=0.93]
# sample:  89%|████████▉ | 178/200 [07:27<00:19,  1.15it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  90%|████████▉ | 179/200 [07:27<00:13,  1.52it/s, 1 steps of size 1.54e-01. acc. prob=0.93]
# sample:  90%|█████████ | 180/200 [07:28<00:14,  1.37it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  90%|█████████ | 181/200 [07:29<00:14,  1.28it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  91%|█████████ | 182/200 [07:30<00:17,  1.03it/s, 11 steps of size 1.54e-01. acc. prob=0.93]
# sample:  92%|█████████▏| 183/200 [07:30<00:13,  1.26it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  92%|█████████▏| 184/200 [07:31<00:10,  1.51it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  92%|█████████▎| 185/200 [07:31<00:08,  1.75it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  93%|█████████▎| 186/200 [07:32<00:08,  1.58it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  94%|█████████▎| 187/200 [07:33<00:08,  1.46it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  94%|█████████▍| 188/200 [07:34<00:10,  1.17it/s, 11 steps of size 1.54e-01. acc. prob=0.92]
# sample:  94%|█████████▍| 189/200 [07:35<00:09,  1.19it/s, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  95%|█████████▌| 190/200 [07:35<00:06,  1.45it/s, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample:  96%|█████████▌| 191/200 [07:37<00:08,  1.12it/s, 11 steps of size 1.54e-01. acc. prob=0.93]
# sample:  96%|█████████▌| 192/200 [07:38<00:09,  1.21s/it, 15 steps of size 1.54e-01. acc. prob=0.93]
# sample:  96%|█████████▋| 193/200 [07:39<00:07,  1.12s/it, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  97%|█████████▋| 194/200 [07:40<00:06,  1.06s/it, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  98%|█████████▊| 195/200 [07:42<00:06,  1.26s/it, 15 steps of size 1.54e-01. acc. prob=0.93]
# sample:  98%|█████████▊| 196/200 [07:43<00:04,  1.17s/it, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample:  98%|█████████▊| 197/200 [07:44<00:03,  1.24s/it, 11 steps of size 1.54e-01. acc. prob=0.93]
# sample:  99%|█████████▉| 198/200 [07:45<00:02,  1.14s/it, 7 steps of size 1.54e-01. acc. prob=0.93]
# sample: 100%|█████████▉| 199/200 [07:47<00:01,  1.33s/it, 11 steps of size 1.54e-01. acc. prob=0.93]
# sample: 100%|██████████| 200/200 [07:47<00:00,  1.05s/it, 3 steps of size 1.54e-01. acc. prob=0.93]
# sample: 100%|██████████| 200/200 [07:47<00:00,  2.34s/it, 3 steps of size 1.54e-01. acc. prob=0.93]
# Bayesian inference time: 484.9 s

# %% [markdown]
# ## 5. Convergence Diagnostics

# %%
param_names = ["G0", "k_d"]
converged = print_convergence(result, param_names)
# Out:
# Convergence Diagnostics
# ==================================================
#  Parameter     R-hat       ESS
# --------------------------------------------------
#         G0    0.9932        40 *
#        k_d    0.9901        36 *
#
# Divergences: 0
# Convergence: CHECK REQUIRED
#
# Note: FAST_MODE uses 1 chain (100 samples). R-hat is a split-chain
#       estimate — less reliable than multi-chain. Thresholds relaxed to
#       R-hat < 1.1, ESS > 40. Use FAST_MODE=False for
#       publication-quality diagnostics (4 chains, 1000 samples).

# %%
display_arviz_diagnostics(result, param_names, fast_mode=os.environ.get("FAST_MODE", "1") == "1")

# %% [markdown]
# ## 6. Posterior Summary

# %%
posterior = result.posterior_samples
nlsq_vals = {"G0": model.G0, "k_d": model.k_d}
print_parameter_table(["G0", "k_d"], nlsq_vals, posterior)
# Out:
# Parameter Comparison
# ==========================================================
#    Param        NLSQ  Bayes (median)                95% CI
# ----------------------------------------------------------
#       G0          99           100.5  [99.66, 101.1]
#      k_d       2.128           2.016  [2, 2.033]

# %% [markdown]
# ### Bayesian Fit Quality Check
#
# The NLSQ warm-start can land in a local minimum for ODE-based models — the LAOS
# loss landscape is non-convex. χ²_red > 1 for the NLSQ prediction is expected and
# informative: it flags that the warm-start is suboptimal, **not** that the model
# is wrong. The Bayesian posterior median is the reliable best-fit estimate, and
# its χ²_red should be close to 1.0.

# %%
posterior = result.posterior_samples
model_bayes = VLBLocal()
model_bayes.parameters.set_value('G0', float(np.median(posterior['G0'])))
model_bayes.parameters.set_value('k_d', float(np.median(posterior['k_d'])))
print(f"Posterior median: G0={model_bayes.G0:.2f} Pa, k_d={model_bayes.k_d:.4f} 1/s")
print("Bayesian median fit quality:")
check_nlsq_fit_quality(
    model_bayes, time_data, stress_data, 'laos',
    noise_sigma=0.03 * np.std(stress_data),
    gamma_0=GAMMA_0, omega=OMEGA,
)
# Out:
# Posterior median: G0=100.46 Pa, k_d=2.0165 1/s
# Bayesian median fit quality:
# ✓  NLSQ fit quality R²=0.9991 ≥ 0.9 — safe to proceed with Bayesian
# ✓  χ²_red = 0.972 ≈ 1.0 — fit consistent with σ=0.144 (absolute) noise
# 0.9991337179483822

# %% [markdown]
# ## 7. Posterior Predictive Check

# %%
posterior = result.posterior_samples
n_draws = min(50, len(posterior['G0']))  # Fewer draws (ODE is slow)

stress_samples = []
for i in range(n_draws):
    model.parameters.set_value('G0', float(posterior['G0'][i]))
    model.parameters.set_value('k_d', float(posterior['k_d'][i]))
    stress_samples.append(np.array(
        model.predict(time_data, test_mode='laos',
                      gamma_0=GAMMA_0, omega=OMEGA)
    ))

stress_arr = np.array(stress_samples)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Waveform PPC
ax1.fill_between(time_data,
    np.percentile(stress_arr, 2.5, axis=0),
    np.percentile(stress_arr, 97.5, axis=0),
    alpha=0.3, color='C0', label='95% CI')
ax1.plot(time_data, np.median(stress_arr, axis=0),
         'C0-', lw=1.5, label='Posterior median')
ax1.plot(time_data, stress_data, 'ko', markersize=2, label='Data')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Stress [Pa]')
ax1.set_title('Waveform PPC')
ax1.legend(fontsize=9)
ax1.grid(True, alpha=0.3)

# Lissajous PPC (overlay several draws)
for i in range(min(10, n_draws)):
    strain_i = GAMMA_0 * np.sin(OMEGA * time_data)
    ax2.plot(strain_i, stress_samples[i], '-', color='C0', alpha=0.15, lw=0.8)
ax2.plot(strain_data, stress_data, 'ko', markersize=2, label='Data')
ax2.set_xlabel('Strain [-]')
ax2.set_ylabel('Stress [Pa]')
ax2.set_title('Lissajous PPC')
ax2.legend(fontsize=9)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)

# %% [markdown]
# ## 8. Save Results

# %%
output_dir = get_output_dir("laos")
save_results(output_dir, model, result, ["G0", "k_d"], {"gamma_0": GAMMA_0, "omega": OMEGA})
print("Done.")
# Out:
# Saved to /home/wei/Documents/GitHub/rheojax/examples/utils/../outputs/vlb/laos/
# Done.

# %% [markdown]
# ## Key Takeaways
#
# 1. **LAOS requires ODE integration** — slower than analytical protocols
# 2. **VLB predicts near-elliptical Lissajous** at moderate amplitudes
# 3. **Bayesian inference works** but is computationally heavier
# 4. **Nonlinear LAOS features** (distorted Lissajous) require
#    Bell or FENE extensions to VLB
# 5. **NLSQ χ²_red > 1 is expected for LAOS** — ODE-based loss landscapes are
#    non-convex and NLSQ can find local minima. R² > 0.99 confirms a plausible
#    warm-start, but χ²_red may be > 1 if k_d is slightly off. NUTS explores
#    the full posterior and recovers the true parameters; use the **Bayesian
#    median χ²_red** as the definitive fit-quality diagnostic.
#
# ## Series Summary
#
# | Protocol | Parameters Identified | Analytical? |
# |-|-|-|
# | Flow curve | η₀ = G₀/k_d only | Yes |
# | Creep | G₀ and k_d | Yes |
# | Relaxation | G₀ and k_d | Yes |
# | Startup | G₀ and k_d | Yes |
# | **SAOS** | **G₀ and k_d (best)** | **Yes** |
# | LAOS | G₀ and k_d | No (ODE) |
