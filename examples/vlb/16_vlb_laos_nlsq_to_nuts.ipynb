# %% [markdown]
# # VLB LAOS: NLSQ → NUTS
#
# **PNAS Digital Rheometer Twin — large-amplitude oscillatory shear**
#
# ## Learning Objectives
#
# - Fit LAOS stress waveform to extract G₀ and k_d
# - Understand ODE-based LAOS prediction (diffrax)
# - Visualize Lissajous figures from posterior draws
#
# ## Data Source
#
# PNAS 2022 Digital Rheometer Twin dataset (LAOS at ω = 1 rad/s).
#
# ## Estimated Runtime
#
# - Fast demo (1 chain): ~3 min (ODE integration per sample)
# - Full run (4 chains): ~10 min
#
# **Note:** LAOS requires ODE integration via diffrax, making it slower than
# analytical protocols.

# %%
import sys

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    # %pip install -q rheojax openpyxl
    import os
    os.environ["JAX_ENABLE_X64"] = "true"

# %%
# %matplotlib inline
import time
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

from rheojax.core.jax_config import safe_import_jax, verify_float64
from rheojax.models import VLBLocal

jax, jnp = safe_import_jax()
verify_float64()
warnings.filterwarnings('ignore', category=FutureWarning)

# Tutorial utilities
import sys

sys.path.insert(0, str(Path('..').resolve()))
from utils.vlb_tutorial_utils import (
    get_bayesian_config,
    get_output_dir,
    load_pnas_laos,
    plot_trace_and_forest,
    print_convergence,
    print_parameter_table,
    save_figure,
    save_results,
)

print(f"JAX version: {jax.__version__}")
import os
import sys

sys.path.insert(0, os.path.dirname(os.path.abspath("")))
from utils.plotting_utils import (
    display_arviz_diagnostics,
    plot_nlsq_fit,
    plot_posterior_predictive,
)
# Out:
# JAX version: 0.8.3

# %% [markdown]
# ## 2. Load Experimental Data

# %%
OMEGA = 1.0  # rad/s
STRAIN_IDX = 5  # Medium amplitude

time_data, strain_data, stress_data = load_pnas_laos(
    omega=OMEGA, strain_amplitude_index=STRAIN_IDX, max_points=200
)
GAMMA_0 = float(np.max(np.abs(strain_data)))

print(f'Data points: {len(time_data)}')
print(f'omega = {OMEGA} rad/s')
print(f'gamma_0 = {GAMMA_0:.4f}')
print(f'Time range: {time_data.min():.3f} - {time_data.max():.1f} s')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(time_data, stress_data, 'ko', markersize=2)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Stress [Pa]')
ax1.set_title('LAOS Stress Waveform')
ax1.grid(True, alpha=0.3)

ax2.plot(strain_data, stress_data, 'ko', markersize=2)
ax2.set_xlabel('Strain [-]')
ax2.set_ylabel('Stress [Pa]')
ax2.set_title('Lissajous Figure (data)')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)
# Out:
# Data points: 200
# omega = 1.0 rad/s
# gamma_0 = 0.5120
# Time range: 0.005 - 66.0 s

# %% [markdown]
# ## 3. VLB Forward Model
#
# For LAOS, the VLB distribution tensor ODE is integrated numerically:
#
# $$\dot{\boldsymbol{\mu}} = k_d(\mathbf{I} - \boldsymbol{\mu}) + \mathbf{L}(t) \cdot \boldsymbol{\mu} + \boldsymbol{\mu} \cdot \mathbf{L}^T(t)$$
#
# with $\mathbf{L}(t) = \gamma_0 \omega \cos(\omega t)$.
#
# This uses diffrax (Tsit5 + PID controller) for JAX-compatible ODE integration.
# At small amplitudes, the response is quasi-linear (single harmonic).

# %% [markdown]
# ## 4. Step 1: NLSQ Point Estimation

# %%
model = VLBLocal()

t0 = time.time()
model.fit(time_data, stress_data, test_mode='laos',
          gamma_0=GAMMA_0, omega=OMEGA, method='scipy')
t_nlsq = time.time() - t0

print(f'NLSQ fit time: {t_nlsq:.2f} s')
print(f'G0  = {model.G0:.1f} Pa')
print(f'k_d = {model.k_d:.4f} 1/s')
print(f'eta_0 = {model.G0 / model.k_d:.1f} Pa*s')

# Predict on data grid
stress_pred = model.predict(time_data, test_mode='laos',
                            gamma_0=GAMMA_0, omega=OMEGA)
ss_res = np.sum((stress_data - np.array(stress_pred))**2)
ss_tot = np.sum((stress_data - np.mean(stress_data))**2)
r2 = 1 - ss_res / ss_tot
print(f'R-squared = {r2:.4f}')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(time_data, stress_data, 'ko', markersize=2, label='Data')
ax1.plot(time_data, stress_pred, 'r-', lw=1.5, label='VLB fit')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Stress [Pa]')
ax1.set_title('LAOS Waveform Fit')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Lissajous comparison
ax2.plot(strain_data, stress_data, 'ko', markersize=2, label='Data')
strain_pred = GAMMA_0 * np.sin(OMEGA * time_data)
ax2.plot(strain_pred, stress_pred, 'r-', lw=1.5, label='VLB fit')
ax2.set_xlabel('Strain [-]')
ax2.set_ylabel('Stress [Pa]')
ax2.set_title('Lissajous Comparison')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)
# Out:
# NLSQ fit time: 26.87 s
# G0  = 157.1 Pa
# k_d = 4.9618 1/s
# eta_0 = 31.7 Pa*s
# R-squared = 0.9299

# %% [markdown]
# ## 4. Step 2: Bayesian Inference (NUTS)
#
# LAOS Bayesian inference is slower due to ODE integration at each evaluation.

# %%
config = get_bayesian_config()
initial_values = {'G0': float(model.G0), 'k_d': float(model.k_d)}
print(f'Config: {config}')
print(f'Warm-start: {initial_values}')

t0 = time.time()
result = model.fit_bayesian(
    time_data, stress_data, test_mode='laos',
    gamma_0=GAMMA_0, omega=OMEGA,
    initial_values=initial_values,
    seed=42,
    **config,
)
t_bayes = time.time() - t0
print(f'\nBayesian inference time: {t_bayes:.1f} s')
# Out:
# Config: {'num_warmup': 50, 'num_samples': 100, 'num_chains': 1}
# Warm-start: {'G0': 157.06458927597953, 'k_d': 4.961816814397178}
#   0%|          | 0/150 [00:00<?, ?it/s]
# warmup:   1%|          | 1/150 [00:03<08:36,  3.47s/it, 1 steps of size 1.95e+00. acc. prob=0.00]
# warmup:   5%|▍         | 7/150 [00:03<00:54,  2.64it/s, 7 steps of size 7.27e-03. acc. prob=0.57]
# warmup:   7%|▋         | 11/150 [00:03<00:32,  4.29it/s, 15 steps of size 1.96e-02. acc. prob=0.72]
# warmup:   9%|▉         | 14/150 [00:04<00:26,  5.11it/s, 63 steps of size 2.44e-03. acc. prob=0.71]
# warmup:  11%|█         | 16/150 [00:04<00:25,  5.32it/s, 23 steps of size 4.88e-03. acc. prob=0.75]
# warmup:  12%|█▏        | 18/150 [00:04<00:21,  6.17it/s, 31 steps of size 9.27e-03. acc. prob=0.77]
# warmup:  14%|█▍        | 21/150 [00:04<00:15,  8.44it/s, 11 steps of size 2.32e-02. acc. prob=0.80]
# warmup:  16%|█▌        | 24/150 [00:05<00:14,  8.98it/s, 63 steps of size 3.97e-03. acc. prob=0.79]
# warmup:  17%|█▋        | 26/150 [00:05<00:14,  8.75it/s, 7 steps of size 7.28e-03. acc. prob=0.80]
# warmup:  19%|█▊        | 28/150 [00:05<00:14,  8.51it/s, 31 steps of size 1.28e-02. acc. prob=0.81]
# warmup:  20%|██        | 30/150 [00:05<00:12,  9.68it/s, 23 steps of size 1.01e-02. acc. prob=0.82]
# warmup:  22%|██▏       | 33/150 [00:05<00:09, 12.27it/s, 7 steps of size 4.99e-03. acc. prob=0.81]
# warmup:  23%|██▎       | 35/150 [00:06<00:11, 10.21it/s, 15 steps of size 8.94e-03. acc. prob=0.82]
# warmup:  25%|██▍       | 37/150 [00:06<00:09, 11.52it/s, 23 steps of size 7.49e-03. acc. prob=0.82]
# warmup:  26%|██▌       | 39/150 [00:06<00:09, 11.72it/s, 15 steps of size 1.22e-02. acc. prob=0.83]
# warmup:  28%|██▊       | 42/150 [00:06<00:07, 14.17it/s, 15 steps of size 2.47e-02. acc. prob=0.84]
# warmup:  29%|██▉       | 44/150 [00:06<00:09, 11.65it/s, 63 steps of size 3.88e-03. acc. prob=0.83]
# warmup:  31%|███       | 46/150 [00:07<00:22,  4.60it/s, 255 steps of size 6.27e-02. acc. prob=0.83]
# warmup:  33%|███▎      | 50/150 [00:08<00:13,  7.37it/s, 15 steps of size 9.27e-02. acc. prob=0.84]
# sample:  35%|███▍      | 52/150 [00:08<00:11,  8.42it/s, 1 steps of size 9.27e-02. acc. prob=0.90]
# sample:  37%|███▋      | 55/150 [00:08<00:09, 10.25it/s, 23 steps of size 9.27e-02. acc. prob=0.94]
# sample:  38%|███▊      | 57/150 [00:08<00:08, 11.55it/s, 15 steps of size 9.27e-02. acc. prob=0.95]
# sample:  39%|███▉      | 59/150 [00:08<00:08, 10.90it/s, 23 steps of size 9.27e-02. acc. prob=0.96]
# sample:  41%|████      | 61/150 [00:08<00:08, 10.04it/s, 31 steps of size 9.27e-02. acc. prob=0.96]
# sample:  43%|████▎     | 64/150 [00:09<00:06, 13.26it/s, 3 steps of size 9.27e-02. acc. prob=0.97]
# sample:  44%|████▍     | 66/150 [00:09<00:07, 11.63it/s, 31 steps of size 9.27e-02. acc. prob=0.97]
# sample:  45%|████▌     | 68/150 [00:09<00:07, 10.65it/s, 31 steps of size 9.27e-02. acc. prob=0.97]
# sample:  47%|████▋     | 70/150 [00:09<00:07, 10.98it/s, 31 steps of size 9.27e-02. acc. prob=0.97]
# sample:  48%|████▊     | 72/150 [00:09<00:07, 10.21it/s, 31 steps of size 9.27e-02. acc. prob=0.97]
# sample:  49%|████▉     | 74/150 [00:10<00:07, 10.69it/s, 15 steps of size 9.27e-02. acc. prob=0.97]
# sample:  51%|█████     | 76/150 [00:10<00:06, 10.77it/s, 31 steps of size 9.27e-02. acc. prob=0.98]
# sample:  52%|█████▏    | 78/150 [00:10<00:06, 10.42it/s, 31 steps of size 9.27e-02. acc. prob=0.98]
# sample:  53%|█████▎    | 80/150 [00:10<00:06, 11.51it/s, 23 steps of size 9.27e-02. acc. prob=0.97]
# sample:  55%|█████▍    | 82/150 [00:10<00:05, 11.78it/s, 15 steps of size 9.27e-02. acc. prob=0.98]
# sample:  56%|█████▌    | 84/150 [00:10<00:05, 11.82it/s, 15 steps of size 9.27e-02. acc. prob=0.97]
# sample:  57%|█████▋    | 86/150 [00:11<00:05, 10.96it/s, 31 steps of size 9.27e-02. acc. prob=0.97]
# sample:  59%|█████▊    | 88/150 [00:11<00:05, 10.70it/s, 15 steps of size 9.27e-02. acc. prob=0.98]
# sample:  60%|██████    | 90/150 [00:11<00:05, 11.63it/s, 7 steps of size 9.27e-02. acc. prob=0.98]
# sample:  61%|██████▏   | 92/150 [00:11<00:05, 10.74it/s, 31 steps of size 9.27e-02. acc. prob=0.98]
# sample:  63%|██████▎   | 94/150 [00:11<00:04, 12.00it/s, 15 steps of size 9.27e-02. acc. prob=0.98]
# sample:  64%|██████▍   | 96/150 [00:12<00:04, 11.12it/s, 31 steps of size 9.27e-02. acc. prob=0.98]
# sample:  65%|██████▌   | 98/150 [00:12<00:04, 12.01it/s, 7 steps of size 9.27e-02. acc. prob=0.98]
# sample:  67%|██████▋   | 101/150 [00:12<00:03, 14.35it/s, 15 steps of size 9.27e-02. acc. prob=0.98]
# sample:  69%|██████▊   | 103/150 [00:12<00:03, 12.79it/s, 31 steps of size 9.27e-02. acc. prob=0.98]
# sample:  70%|███████   | 105/150 [00:12<00:03, 13.47it/s, 3 steps of size 9.27e-02. acc. prob=0.98]
# sample:  71%|███████▏  | 107/150 [00:12<00:03, 12.96it/s, 15 steps of size 9.27e-02. acc. prob=0.98]
# sample:  73%|███████▎  | 109/150 [00:12<00:03, 12.54it/s, 27 steps of size 9.27e-02. acc. prob=0.98]
# sample:  74%|███████▍  | 111/150 [00:13<00:02, 13.00it/s, 19 steps of size 9.27e-02. acc. prob=0.98]
# sample:  76%|███████▌  | 114/150 [00:13<00:02, 15.97it/s, 11 steps of size 9.27e-02. acc. prob=0.97]
# sample:  77%|███████▋  | 116/150 [00:13<00:02, 14.42it/s, 15 steps of size 9.27e-02. acc. prob=0.97]
# sample:  79%|███████▊  | 118/150 [00:13<00:02, 13.27it/s, 15 steps of size 9.27e-02. acc. prob=0.97]
# sample:  80%|████████  | 120/150 [00:13<00:02, 12.45it/s, 19 steps of size 9.27e-02. acc. prob=0.98]
# sample:  83%|████████▎ | 124/150 [00:13<00:01, 15.56it/s, 23 steps of size 9.27e-02. acc. prob=0.98]
# sample:  84%|████████▍ | 126/150 [00:14<00:01, 14.93it/s, 15 steps of size 9.27e-02. acc. prob=0.98]
# sample:  85%|████████▌ | 128/150 [00:14<00:01, 12.13it/s, 31 steps of size 9.27e-02. acc. prob=0.98]
# sample:  87%|████████▋ | 130/150 [00:14<00:01, 12.82it/s, 23 steps of size 9.27e-02. acc. prob=0.98]
# sample:  89%|████████▊ | 133/150 [00:14<00:01, 14.72it/s, 23 steps of size 9.27e-02. acc. prob=0.97]
# sample:  90%|█████████ | 135/150 [00:14<00:01, 13.72it/s, 31 steps of size 9.27e-02. acc. prob=0.98]
# sample:  91%|█████████▏| 137/150 [00:15<00:01, 11.88it/s, 31 steps of size 9.27e-02. acc. prob=0.98]
# sample:  93%|█████████▎| 139/150 [00:15<00:00, 12.49it/s, 23 steps of size 9.27e-02. acc. prob=0.98]
# sample:  94%|█████████▍| 141/150 [00:15<00:00, 12.69it/s, 15 steps of size 9.27e-02. acc. prob=0.98]
# sample:  95%|█████████▌| 143/150 [00:15<00:00, 13.62it/s, 3 steps of size 9.27e-02. acc. prob=0.97]
# sample:  97%|█████████▋| 145/150 [00:15<00:00, 14.55it/s, 11 steps of size 9.27e-02. acc. prob=0.98]
# sample:  98%|█████████▊| 147/150 [00:15<00:00, 15.37it/s, 15 steps of size 9.27e-02. acc. prob=0.98]
# sample: 100%|██████████| 150/150 [00:15<00:00, 16.31it/s, 31 steps of size 9.27e-02. acc. prob=0.97]
# sample: 100%|██████████| 150/150 [00:15<00:00,  9.47it/s, 31 steps of size 9.27e-02. acc. prob=0.97]
# Bayesian inference time: 22.8 s

# %% [markdown]
# ## 5. Convergence Diagnostics

# %%
param_names = ["G0", "k_d"]
converged = print_convergence(result, param_names)
# Out:
# Convergence Diagnostics
# ==================================================
#  Parameter     R-hat       ESS
# --------------------------------------------------
#         G0    0.9900        47 *
#        k_d    0.9899        48 *
#
# Divergences: 0
# Convergence: CHECK REQUIRED

# %%
display_arviz_diagnostics(result, param_names, fast_mode=os.environ.get("FAST_MODE", "1") == "1")

# %% [markdown]
# ## 6. Posterior Summary

# %%
posterior = result.posterior_samples
nlsq_vals = {"G0": model.G0, "k_d": model.k_d}
print_parameter_table(["G0", "k_d"], nlsq_vals, posterior)
# Out:
# Parameter Comparison
# ==========================================================
#    Param        NLSQ  Bayes (median)                95% CI
# ----------------------------------------------------------
#       G0       157.1           91.78  [85.06, 99.91]
#      k_d       4.962           2.756  [2.508, 3.002]

# %% [markdown]
# ## 7. Posterior Predictive Check

# %%
posterior = result.posterior_samples
n_draws = min(50, len(posterior['G0']))  # Fewer draws (ODE is slow)

stress_samples = []
for i in range(n_draws):
    model.parameters.set_value('G0', float(posterior['G0'][i]))
    model.parameters.set_value('k_d', float(posterior['k_d'][i]))
    stress_samples.append(np.array(
        model.predict(time_data, test_mode='laos',
                      gamma_0=GAMMA_0, omega=OMEGA)
    ))

stress_arr = np.array(stress_samples)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Waveform PPC
ax1.fill_between(time_data,
    np.percentile(stress_arr, 2.5, axis=0),
    np.percentile(stress_arr, 97.5, axis=0),
    alpha=0.3, color='C0', label='95% CI')
ax1.plot(time_data, np.median(stress_arr, axis=0),
         'C0-', lw=1.5, label='Posterior median')
ax1.plot(time_data, stress_data, 'ko', markersize=2, label='Data')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Stress [Pa]')
ax1.set_title('Waveform PPC')
ax1.legend(fontsize=9)
ax1.grid(True, alpha=0.3)

# Lissajous PPC (overlay several draws)
for i in range(min(10, n_draws)):
    strain_i = GAMMA_0 * np.sin(OMEGA * time_data)
    ax2.plot(strain_i, stress_samples[i], '-', color='C0', alpha=0.15, lw=0.8)
ax2.plot(strain_data, stress_data, 'ko', markersize=2, label='Data')
ax2.set_xlabel('Strain [-]')
ax2.set_ylabel('Stress [Pa]')
ax2.set_title('Lissajous PPC')
ax2.legend(fontsize=9)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)

# %% [markdown]
# ## 8. Save Results

# %%
output_dir = get_output_dir("laos")
save_results(output_dir, model, result, ["G0", "k_d"], {"gamma_0": GAMMA_0, "omega": OMEGA})
print("Done.")
# Out:
# Saved to /Users/b80985/Projects/rheojax/examples/utils/../outputs/vlb/laos/
# Done.

# %% [markdown]
# ## Key Takeaways
#
# 1. **LAOS requires ODE integration** — slower than analytical protocols
# 2. **VLB predicts near-elliptical Lissajous** at moderate amplitudes
# 3. **Bayesian inference works** but is computationally heavier
# 4. **Nonlinear LAOS features** (distorted Lissajous) require
#    Bell or FENE extensions to VLB
#
# ## Series Summary
#
# | Protocol | Parameters Identified | Analytical? |
# |-|-|-|
# | Flow curve | η₀ = G₀/k_d only | Yes |
# | Creep | G₀ and k_d | Yes |
# | Relaxation | G₀ and k_d | Yes |
# | Startup | G₀ and k_d | Yes |
# | **SAOS** | **G₀ and k_d (best)** | **Yes** |
# | LAOS | G₀ and k_d | No (ODE) |
