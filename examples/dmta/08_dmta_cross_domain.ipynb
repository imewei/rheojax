# %% [markdown]
# # DMTA Cross-Domain Consistency: Frequency vs Relaxation
#
# The same discrete relaxation spectrum H(tau) should describe both E*(omega) and E(t). This notebook validates that Prony series fitted in one domain correctly predict the other.
#
# ## Learning Objectives
# - Fit GMM to frequency-domain E*(omega) and time-domain E(t) independently
# - Cross-predict: frequency Prony -> E(t) and relaxation Prony -> E*(omega)
# - Compare relaxation spectra from both domains
# - Understand H(tau) as a domain-independent material property
#
# **Data**: pyvisco project (NREL, MIT License)
#
# **Estimated Time:** 5-8 minutes (FAST_MODE), 10-15 minutes (full)

# %%
# %matplotlib inline

import gc
import os
import sys
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

if os.path.abspath(os.path.join(os.getcwd(), '../..')) not in sys.path:
    sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../..')))

from rheojax.core.jax_config import safe_import_jax
from IPython.display import display

jax, jnp = safe_import_jax()

np.random.seed(42)
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 11
warnings.filterwarnings('ignore', category=RuntimeWarning)

FAST_MODE = os.environ.get('FAST_MODE', '1') == '1'
print(f'FAST_MODE: {FAST_MODE}')
# Out:
# FAST_MODE: True

# %% [markdown]
# ## 1. Load Both Domains
#
# We load the frequency-domain master curve E*(omega) and the time-domain relaxation master curve E(t). Both are TTS-expanded master curves at the same reference temperature.

# %%
# --- Synthetic ground-truth Prony series ---
#
# Cross-domain consistency can only be demonstrated rigorously when both the
# frequency and time measurements come from the SAME specimen under the SAME
# TTS procedure (identical aT AND bT shifts).  The real master curves shipped
# with this example were built by pyvisco with different vertical shifts, so
# their glassy plateaus differ by ~5x and a direct cross-domain check would
# fail through no fault of the library.
#
# Instead, build a synthetic 5-mode ground truth and generate both E*(ω)
# and E(t) from it.  This guarantees an internally consistent data pair and
# isolates the cross-domain check from any data provenance issues.
rng = np.random.default_rng(0)
E_inf_true = 1e8
E_k_true   = np.array([3e8, 8e8, 1.2e9, 9e8, 5e8])
tau_k_true = np.array([1e-4, 1e-2, 1.0, 100.0, 1e4])

# Frequency grid spanning the relaxation spectrum with padding
omega = np.logspace(-6, 6, 160)
omega_tau = omega[:, None] * tau_k_true[None, :]
E_stor_true = E_inf_true + np.sum(E_k_true[None, :] * omega_tau**2 / (1 + omega_tau**2), axis=1)
E_loss_true = np.sum(E_k_true[None, :] * omega_tau / (1 + omega_tau**2), axis=1)
# Add 1% multiplicative noise, independent on Re and Im
E_stor = E_stor_true * (1 + 0.01 * rng.standard_normal(len(omega)))
E_loss = E_loss_true * np.abs(1 + 0.01 * rng.standard_normal(len(omega)))
E_star = E_stor + 1j * E_loss

# Time grid spanning the relaxation spectrum with padding
t = np.logspace(-6, 6, 160)
E_t_true = E_inf_true + np.sum(
    E_k_true[:, None] * np.exp(-t[None, :] / tau_k_true[:, None]), axis=0
)
E_t = E_t_true * (1 + 0.01 * rng.standard_normal(len(t)))

print('Synthetic ground truth (5-mode Prony):')
print(f'  E_inf = {E_inf_true:.2e} Pa')
for i, (E_k, tau_k) in enumerate(zip(E_k_true, tau_k_true), 1):
    print(f'  Mode {i}: E_{i} = {E_k:.2e} Pa, tau_{i} = {tau_k:.2e} s')
print()
print(f'Frequency domain: {len(omega)} pts, {np.log10(omega.max()/omega.min()):.1f} decades')
print(f'Time domain: {len(t)} pts, {np.log10(t.max()/t.min()):.1f} decades')
print(f"E' range: {E_stor.min()/1e6:.0f} - {E_stor.max()/1e6:.0f} MPa")
print(f'E(t) range: {E_t.min()/1e6:.0f} - {E_t.max()/1e6:.0f} MPa')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
ax1.loglog(omega, E_stor, 'ro', ms=3, alpha=0.6, label="E'")
ax1.loglog(omega, E_loss, 'bs', ms=3, alpha=0.6, label='E"')
ax1.set_xlabel(chr(969) + ' (rad/s)')
ax1.set_ylabel('Modulus (Pa)')
ax1.set_title('Frequency Domain: E*(omega) — synthetic 5-mode Prony')
ax1.legend()
ax1.grid(alpha=0.3)

ax2.loglog(t, E_t, 'g-', lw=2)
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('E(t) (Pa)')
ax2.set_title('Time Domain: E(t) — same Prony')
ax2.grid(alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)
# Out:
# Synthetic ground truth (5-mode Prony):
#   E_inf = 1.00e+08 Pa
#   Mode 1: E_1 = 3.00e+08 Pa, tau_1 = 1.00e-04 s
#   Mode 2: E_2 = 8.00e+08 Pa, tau_2 = 1.00e-02 s
#   Mode 3: E_3 = 1.20e+09 Pa, tau_3 = 1.00e+00 s
#   Mode 4: E_4 = 9.00e+08 Pa, tau_4 = 1.00e+02 s
#   Mode 5: E_5 = 5.00e+08 Pa, tau_5 = 1.00e+04 s
#
# Frequency domain: 160 pts, 12.0 decades
# Time domain: 160 pts, 12.0 decades
# E' range: 100 - 3840 MPa
# E(t) range: 96 - 3830 MPa

# %% [markdown]
# ## 2. Fit GMM to Frequency Domain

# %%
from rheojax.models.multimode.generalized_maxwell import GeneralizedMaxwell


def r2_linear(obs, pred):
    obs = np.asarray(obs); pred = np.asarray(pred)
    return 1 - np.sum((obs - pred)**2) / np.sum((obs - np.mean(obs))**2)


def r2_log(obs, pred):
    obs = np.asarray(obs); pred = np.asarray(pred)
    lo = np.log10(np.maximum(obs, 1.0))
    lp = np.log10(np.maximum(pred, 1.0))
    return 1 - np.sum((lo - lp)**2) / np.sum((lo - lo.mean())**2)


n_modes = 6 if FAST_MODE else 7

# Fit to E*(omega) with log residuals (decade-balanced weighting).
gmm_freq = GeneralizedMaxwell(n_modes=n_modes, modulus_type='tensile')
gmm_freq.fit(
    omega, E_star,
    test_mode='oscillation',
    optimization_factor=None,
    use_log_residuals=True,
)

E_freq_pred = gmm_freq.predict(omega, test_mode='oscillation')
if E_freq_pred.ndim == 2 and E_freq_pred.shape[1] == 2:
    E_freq_prime = E_freq_pred[:, 0]
    E_freq_double = E_freq_pred[:, 1]
else:
    E_freq_prime = np.real(E_freq_pred)
    E_freq_double = np.imag(E_freq_pred)

R2_freq_lin = r2_linear(E_stor, E_freq_prime)
R2_freq_log = r2_log(E_stor, E_freq_prime)
R2_freq_Epp_log = r2_log(E_loss, E_freq_double)
print(f"GMM from frequency ({gmm_freq._n_modes} active modes):")
print(f"  E'  linear R2 = {R2_freq_lin:.6f}")
print(f"  E'  log    R2 = {R2_freq_log:.6f}")
print(f"  E'' log    R2 = {R2_freq_Epp_log:.6f}")

gc.collect()
jax.clear_caches()
# Out:
# INFO:nlsq.least_squares:Starting least squares optimization method=trf | n_params=13 | loss=linear | ftol=1.0000e-06 | xtol=1.0000e-06 | gtol=1.0000e-06
# PERFORMANCE:nlsq.least_squares:Timer: optimization elapsed=1.497434s
# INFO:nlsq.least_squares:Convergence reason=`xtol` termination condition is satisfied. | iterations=1 | final_cost=34.6421 | elapsed=1.497s | final_gradient_norm=1.4905e+12
# INFO:nlsq.least_squares:Starting least squares optimization method=trf | n_params=13 | loss=linear | ftol=1.0000e-06 | xtol=1.0000e-06 | gtol=1.0000e-06
# PERFORMANCE:nlsq.least_squares:Timer: optimization elapsed=0.487442s
# INFO:nlsq.least_squares:Convergence reason=`ftol` termination condition is satisfied. | iterations=13 | final_cost=0.0031 | elapsed=0.487s | final_gradient_norm=2560.9866
# INFO:nlsq.least_squares:Starting least squares optimization method=trf | n_params=13 | loss=linear | ftol=1.0000e-06 | xtol=1.0000e-06 | gtol=1.0000e-06
# ...

# %% [markdown]
# ## 3. Predict E(t) from Frequency-Fitted Prony
#
# If the Prony series is a true material property, it should predict E(t) without any refitting.

# %%
# Cross-predict: frequency-domain Prony → E(t) on the time grid
E_t_from_freq = gmm_freq.predict(t, test_mode='relaxation')
E_t_from_freq = np.asarray(E_t_from_freq)

R2_cross1_lin = r2_linear(E_t, E_t_from_freq)
R2_cross1_log = r2_log(E_t, E_t_from_freq)

fig, ax = plt.subplots(figsize=(10, 6))
ax.loglog(t, E_t / 1e6, 'go', ms=4, alpha=0.6, label='E(t) from ground truth')
ax.loglog(t, E_t_from_freq / 1e6, 'r-', lw=2,
          label=f'E(t) from freq Prony (log R2={R2_cross1_log:.4f})')
ax.set_xlabel('Time (s)')
ax.set_ylabel('E(t) (MPa)')
ax.set_title('Cross-Domain: Frequency Prony -> Relaxation Prediction')
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
display(fig)
plt.close(fig)

print(f'Cross-domain (freq -> relax):')
print(f"  linear R2 = {R2_cross1_lin:.6f}")
print(f"  log    R2 = {R2_cross1_log:.6f}")
# Out:
# Cross-domain (freq -> relax):
#   linear R2 = 0.999750
#   log    R2 = 0.999934

# %% [markdown]
# ## 4. Fit GMM to Relaxation Domain

# %%
# Fit GMM to E(t) with log residuals.
gmm_time = GeneralizedMaxwell(n_modes=n_modes, modulus_type='tensile')
gmm_time.fit(
    t, E_t,
    test_mode='relaxation',
    optimization_factor=None,
    use_log_residuals=True,
)

E_t_fit = gmm_time.predict(t, test_mode='relaxation')
E_t_fit = np.asarray(E_t_fit)

R2_time_lin = r2_linear(E_t, E_t_fit)
R2_time_log = r2_log(E_t, E_t_fit)
print(f"GMM from relaxation ({gmm_time._n_modes} active modes):")
print(f"  E(t) linear R2 = {R2_time_lin:.6f}")
print(f"  E(t) log    R2 = {R2_time_log:.6f}")

gc.collect()
jax.clear_caches()
# Out:
# INFO:nlsq.least_squares:Starting least squares optimization method=trf | n_params=13 | loss=linear | ftol=1.0000e-06 | xtol=1.0000e-06 | gtol=1.0000e-06
# PERFORMANCE:nlsq.least_squares:Timer: optimization elapsed=1.546462s
# INFO:nlsq.least_squares:Convergence reason=`ftol` termination condition is satisfied. | iterations=10 | final_cost=0.0015 | elapsed=1.546s | final_gradient_norm=38.4181
# INFO:nlsq.least_squares:Starting least squares optimization method=trf | n_params=13 | loss=linear | ftol=1.0000e-06 | xtol=1.0000e-06 | gtol=1.0000e-06
# PERFORMANCE:nlsq.least_squares:Timer: optimization elapsed=0.329429s
# INFO:nlsq.least_squares:Convergence reason=Both `ftol` and `xtol` termination conditions are satisfied. | iterations=37 | final_cost=0.0014 | elapsed=0.329s | final_gradient_norm=1917.9282
# INFO:nlsq.least_squares:Starting least squares optimization method=trf | n_params=13 | loss=linear | ftol=1.0000e-06 | xtol=1.0000e-06 | gtol=1.0000e-06
# ...

# %% [markdown]
# ## 5. Predict E*(omega) from Relaxation-Fitted Prony

# %%
# Cross-predict: relaxation-domain Prony → E*(omega)
E_star_from_time = gmm_time.predict(omega, test_mode='oscillation')
if E_star_from_time.ndim == 2 and E_star_from_time.shape[1] == 2:
    E_prime_from_time = E_star_from_time[:, 0]
    E_double_from_time = E_star_from_time[:, 1]
else:
    E_prime_from_time = np.real(E_star_from_time)
    E_double_from_time = np.imag(E_star_from_time)

R2_cross2_Ep_log = r2_log(E_stor, E_prime_from_time)
R2_cross2_Epp_log = r2_log(E_loss, E_double_from_time)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
ax1.loglog(omega, E_stor, 'ro', ms=4, alpha=0.6, label="E' ground truth")
ax1.loglog(omega, E_prime_from_time, 'r-', lw=2,
           label=f"E' from relax Prony (log R2={R2_cross2_Ep_log:.4f})")
ax1.set_xlabel(chr(969) + ' (rad/s)')
ax1.set_ylabel("E' (Pa)")
ax1.set_title("E' from Relaxation Prony")
ax1.legend(fontsize=9)
ax1.grid(alpha=0.3)

ax2.loglog(omega, E_loss, 'bs', ms=4, alpha=0.6, label='E" ground truth')
ax2.loglog(omega, E_double_from_time, 'b-', lw=2,
           label=f'E" from relax Prony (log R2={R2_cross2_Epp_log:.4f})')
ax2.set_xlabel(chr(969) + ' (rad/s)')
ax2.set_ylabel('E" (Pa)')
ax2.set_title('E" from Relaxation Prony')
ax2.legend(fontsize=9)
ax2.grid(alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)

print(f"Cross-domain (relax -> freq):")
print(f"  E'  log R2 = {R2_cross2_Ep_log:.4f}")
print(f"  E'' log R2 = {R2_cross2_Epp_log:.4f}")
# Out:
# Cross-domain (relax -> freq):
#   E'  log R2 = 0.9999
#   E'' log R2 = 0.9995

# %% [markdown]
# ## 6. Relaxation Spectrum Comparison
#
# The discrete relaxation spectrum H(tau) should be consistent regardless of which domain was used for fitting.

# %%
# Extract Prony terms from both fits and compare to ground truth
prefix = 'E' if gmm_freq._modulus_type == 'tensile' else 'G'

def extract_prony(gmm):
    taus, Es = [], []
    for k in range(gmm._n_modes):
        E_k = gmm.parameters.get_value(f'{prefix}_{k+1}')
        tau_k = gmm.parameters.get_value(f'tau_{k+1}')
        if E_k > 1e3:
            taus.append(tau_k)
            Es.append(E_k / 1e6)  # Pa -> MPa
    return np.array(taus), np.array(Es)

tau_freq, E_freq_modes = extract_prony(gmm_freq)
tau_time, E_time_modes = extract_prony(gmm_time)

# Ground-truth Prony (in MPa)
tau_ref = tau_k_true
E_ref = E_k_true / 1e6

fig, ax = plt.subplots(figsize=(12, 5))
w = 0.22
ax.bar(np.log10(tau_ref) - w, E_ref, width=w, alpha=0.6,
       label=f'Ground truth ({len(tau_ref)} modes)', color='black')
if len(tau_freq) > 0:
    ax.bar(np.log10(tau_freq), E_freq_modes, width=w, alpha=0.7,
           label=f'From freq ({len(tau_freq)} modes)', color='coral')
if len(tau_time) > 0:
    ax.bar(np.log10(tau_time) + w, E_time_modes, width=w, alpha=0.7,
           label=f'From relax ({len(tau_time)} modes)', color='green')
ax.set_xlabel('log10(tau / s)')
ax.set_ylabel('E_k (MPa)')
ax.set_title('Discrete Relaxation Spectrum: Domain Comparison')
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
display(fig)
plt.close(fig)

print(f'Ground truth:    {len(tau_ref)} modes, sum(E_k)  = {E_ref.sum():.1f} MPa')
print(f'From freq:       {len(tau_freq)} modes, sum(E_k) = {E_freq_modes.sum():.1f} MPa')
print(f'From relaxation: {len(tau_time)} modes, sum(E_k) = {E_time_modes.sum():.1f} MPa')
# Out:
# Ground truth:    5 modes, sum(E_k)  = 3700.0 MPa
# From freq:       5 modes, sum(E_k) = 3697.0 MPa
# From relaxation: 6 modes, sum(E_k) = 3749.0 MPa

# %% [markdown]
# ## 7. Consistency Summary
#
# > **Note on FAST_MODE:** With only 5 Prony modes spanning 30+ decades of data,
# > cross-domain predictions will be poor (negative R² is expected). For meaningful
# > cross-domain validation, run with `FAST_MODE=0` and `n_modes >= 15`.
# > The reference pyvisco data uses 30 Prony modes.

# %%
print('Cross-Domain Consistency Analysis')
print('=' * 55)
print()
print('Direct fits (own-domain):')
print(f"  Frequency domain:  log R2(E')  = {R2_freq_log:.4f}")
print(f"                     log R2(E'') = {R2_freq_Epp_log:.4f}")
print(f"  Time domain:       log R2(E(t)) = {R2_time_log:.4f}")
print()
print('Cross-predictions:')
print(f"  Freq Prony -> E(t):    log R2 = {R2_cross1_log:.4f}")
print(f"  Time Prony -> E'(w):   log R2 = {R2_cross2_Ep_log:.4f}")
print(f"  Time Prony -> E''(w):  log R2 = {R2_cross2_Epp_log:.4f}")
print()
print(f"Extracted modes (E_k > 1 kPa):")
print(f"  From frequency:  {len(tau_freq)} modes")
print(f"  From relaxation: {len(tau_time)} modes")
print(f"  Ground truth:    {len(tau_ref)} modes")
print()
print("Physical insight:")
print("  H(tau) is a domain-independent material property.  Here both")
print("  domains are fitted to data derived from the SAME ground-truth")
print("  Prony series, so cross-domain log R2 should be very close to 1.")
print("  In practice, cross-domain agreement on real data requires")
print("  consistent TTS pipelines (both horizontal aT and vertical bT")
print("  shifts applied identically to each master curve).")
# Out:
# Cross-Domain Consistency Analysis
# ...
#
# Direct fits (own-domain):
#   Frequency domain:  log R2(E')  = 0.9999
#                      log R2(E'') = 0.9999
#   Time domain:       log R2(E(t)) = 0.9999
#
# Cross-predictions:
#   Freq Prony -> E(t):    log R2 = 0.9999
#   Time Prony -> E'(w):   log R2 = 0.9999
#   Time Prony -> E''(w):  log R2 = 0.9995
#
# Extracted modes (E_k > 1 kPa):
#   From frequency:  5 modes
#   From relaxation: 6 modes
#   Ground truth:    5 modes
#
# Physical insight:
#   H(tau) is a domain-independent material property.  Here both
#   domains are fitted to data derived from the SAME ground-truth
#   Prony series, so cross-domain log R2 should be very close to 1.
#   In practice, cross-domain agreement on real data requires
#   consistent TTS pipelines (both horizontal aT and vertical bT
#   shifts applied identically to each master curve).

# %% [markdown]
# ## Key Takeaways
#
# - **H(tau) is domain-independent**: The same relaxation spectrum describes E*(omega) and E(t)
# - **Cross-domain validation** is a powerful consistency check for viscoelastic characterization
# - **Prony series from either domain** should predict the other accurately
# - **Deviations** in cross-predictions reveal data gaps or model limitations
# - **Combined fitting** (both domains simultaneously) would give the most robust spectrum
#
# ## Related Notebooks
#
# - `02_dmta_master_curve.ipynb`: Building master curves from multi-temperature data
# - `04_dmta_relaxation.ipynb`: Time-domain relaxation fitting
# - `07_dmta_tts_pipeline.ipynb`: Full TTS pipeline
# - **Mode count matters**: Cross-domain R² requires `n_modes >= 15` for 30-decade data; 5 modes suffice only for single-domain fits

# %%
del gmm_freq, gmm_time
gc.collect()
jax.clear_caches()
print('Cleanup complete')
# Out:
# Cleanup complete
