# %% [markdown]
# # ITT-MCT Isotropic Model: Stress Relaxation
#
# ## Learning Objectives
#
# 1. Generate **synthetic relaxation data** from NB07 calibrated parameters
# 2. Understand **two-step relaxation** in ISM (β and α processes)
# 3. Analyze the **k-resolved non-ergodicity parameter**
# 4. Fit the model to verify parameter recovery
#
# ## Prerequisites
#
# - **NB07: ISM Flow Curve** (required for calibrated parameters)
#
# ## Runtime
#
# - Fast demo (NUM_CHAINS=1, NUM_SAMPLES=500): ~3-5 minutes
# - Full run (NUM_CHAINS=4, NUM_SAMPLES=2000): ~15-20 minutes

# %% [markdown]
# ## 1. Setup

# %%
# Google Colab setup
import sys

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    # %pip install -q rheojax
    import os
    os.environ["JAX_ENABLE_X64"] = "true"
    print("RheoJAX installed successfully.")

# %%
# Imports
# %matplotlib inline
import os
import sys
import time

import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

from rheojax.core.jax_config import safe_import_jax, verify_float64
from rheojax.models.itt_mct import ITTMCTIsotropic

# Add examples/utils to path
sys.path.insert(0, os.path.dirname(os.path.abspath("")))
from utils.itt_mct_tutorial_utils import (
    compute_fit_quality,
    generate_synthetic_relaxation_isotropic,
    get_isotropic_param_names,
    load_itt_mct_parameters,
    print_convergence_summary,
    print_glass_state_summary,
    print_parameter_comparison,
    save_itt_mct_results,
    set_model_parameters,
)
from utils.plotting_utils import (
    display_arviz_diagnostics,
    plot_nlsq_fit,
    plot_posterior_predictive,
)

jax, jnp = safe_import_jax()
verify_float64()

# FAST_MODE: reduced Bayesian samples for CI; set FAST_MODE=0 for production
FAST_MODE = os.environ.get("FAST_MODE", "1") == "1"

print(f"JAX version: {jax.__version__}")
print(f"Devices: {jax.devices()}")
print(f"FAST_MODE: {FAST_MODE}")
# Out:
# WARNING:jax._src.xla_bridge:An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# GPU AVAILABLE BUT NOT USED
# ...
#   GPU: NVIDIA GeForce RTX 4090 Laptop GPU (SM 8.9)
#   System CUDA: 13.1
#   JAX backend: CPU-only
#
# Enable 20-100x speedup:
#   make install-jax-gpu
#
# Or manually:
#   pip uninstall -y jax jaxlib jax-cuda13-plugin jax-cuda13-pjrt jax-cuda12-plugin jax-cuda12-pjrt
#   pip install "jax[cuda13-local]"
#
# Note: GPU acceleration is supported on Linux only.
# See README.md for details.
# JAX version: 0.10.2
# Devices: [CpuDevice(id=0)]
# FAST_MODE: True

# %% [markdown]
# ## 2. Theory: ISM Stress Relaxation
#
# ### k-Resolved Two-Step Relaxation
#
# In the ISM, each wave vector mode has its own correlator Φ(k,t):
#
# 1. **Fast β-process**: Short-time decay from particle vibrations
# 2. **Slow α-process**: Long-time decay from cage rearrangement
#
# ### Key Equations
#
# **k-resolved correlator**:
# $$
# \frac{\partial \Phi(k,t)}{\partial t} + \Gamma(k)\left[\Phi(k,t) + \int_0^t m(k,t-s) \frac{\partial \Phi(k,s)}{\partial s} ds\right] = 0
# $$
#
# **Stress relaxation**:
# $$
# \sigma(t) = \gamma_0 \frac{k_BT}{6\pi^2} \int dk \, k^4 S(k)^2 \left[\frac{\partial \ln S}{\partial \ln k}\right]^2 \Phi(k,t)^2 h(\gamma_0)
# $$
#
# ### ISM vs Schematic Relaxation
#
# | Aspect | Schematic | ISM |
# |--------|-----------|-----|
# | Correlator | Single Φ(t) | k-resolved Φ(k,t) |
# | Decay | Averaged | k-dependent rates |
# | Plateau | f | f(k) integrated |

# %% [markdown]
# ## 3. Load Calibrated Parameters from NB07

# %%
# TRUE_PARAMS positive control. Why not load from NB07: NB07 saved
# only the fittable params (D0, gamma_c), and gamma_c there landed in
# a degenerate basin at ~0.018 (NB07's flow-curve fit). Combined with
# SIGMA_0=100 Pa and model-native G_scale=kBT/σ_d³≈4 mPa, the implied
# pre-shear γ_pre = 100/0.004 = 24390 — and γ_pre/γ_c ≈ 10⁶ makes
# h(γ_pre)=exp(-(γ_pre/γ_c)²) numerically zero, so every relaxation
# sample is identically 0. Pin to TRUE_PARAMS and use σ₀ in linear regime.
TRUE_PARAMS = {
    "phi": 0.55,
    "sigma_d": 1e-6,
    "D0": 1e-12,
    "kBT": 4.1e-21,
    "gamma_c": 0.10,
}
params = dict(TRUE_PARAMS)

print("Ground-truth parameters (hidden from fit):")
for _n, _v in TRUE_PARAMS.items():
    print(f"  {_n:10s} = {_v}")
# Out:
# Ground-truth parameters (hidden from fit):
#   phi        = 0.55
#   sigma_d    = 1e-06
#   D0         = 1e-12
#   kBT        = 4.1e-21
#   gamma_c    = 0.1

# %%
# Create truth model + fitting model from TRUE_PARAMS.
truth_model = ITTMCTIsotropic(phi=TRUE_PARAMS["phi"])
set_model_parameters(truth_model, TRUE_PARAMS)
truth_model.update_structure_factor()

model = ITTMCTIsotropic(phi=TRUE_PARAMS["phi"])
set_model_parameters(model, TRUE_PARAMS)
model.update_structure_factor()

print("\nTruth model state:")
print(truth_model)
print()
print_glass_state_summary(truth_model)
# Out:
# Truth model state:
# ITTMCTIsotropic(φ=0.550 [glass], n_k=100, sk_source='percus_yevick')
#
#
# Glass Transition State
# ...
# State: GLASS
# Volume fraction: phi = 0.5500
# MCT transition: phi_MCT = 0.5160
#   -> phi > phi_MCT: cage effect dominates
#   -> Material shows yield stress

# %% [markdown]
# ## 4. Generate Synthetic Relaxation Data

# %%
# Generate synthetic relaxation data from truth_model.predict.
#
# The ISM stress integral is now properly dimensionless (isotropic.py
# uses q = k·σ_d integration with the (1/60π²) MCT prefactor), so the
# output is in physical Pa. At φ=0.55, σ_d=1µm: expected plateau is on
# the order of kBT/σ_d³ × dimensionless ~ tens of mPa.
gamma_pre = TRUE_PARAMS["gamma_c"] / 2.0   # = 0.05, linear regime
T_END = 100.0
NOISE_LEVEL = 0.03

time_data = np.logspace(-2, np.log10(T_END), 80)
stress_clean = np.asarray(
    truth_model.predict(time_data, test_mode="relaxation", gamma_pre=gamma_pre)
)

rng = np.random.default_rng(seed=42)
log_noise = rng.normal(0.0, NOISE_LEVEL, size=stress_clean.shape)
stress_data = np.maximum(stress_clean, 1e-30) * np.exp(log_noise)

print(f"γ_pre = γ_c/2 = {gamma_pre:.4f}")
print(f"Generated {len(time_data)} data points")
print(f"Time range: [{time_data.min():.4f}, {time_data.max():.2f}] s")
print(f"Stress range: [{stress_data.min():.4g}, {stress_data.max():.4g}] Pa")
# Out:
# γ_pre = γ_c/2 = 0.0500
# Generated 80 data points
# Time range: [0.0100, 100.00] s
# Stress range: [0.02622, 0.038] Pa

# %%
# gamma_pre is already defined in cell 9 and is the pre-shear strain
# passed to predict/fit calls. Print it here for visibility.
print(f"Pre-shear strain (experimental condition): γ_pre = {gamma_pre:.4f}")
print(f"Critical strain γ_c = {TRUE_PARAMS['gamma_c']:.4f}")
print(f"Linear regime (γ_pre < γ_c): {gamma_pre < TRUE_PARAMS['gamma_c']}")
# Out:
# Pre-shear strain (experimental condition): γ_pre = 0.0500
# Critical strain γ_c = 0.1000
# Linear regime (γ_pre < γ_c): True

# %%
# Plot synthetic data in physical Pa.
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(time_data, stress_data, "ko", markersize=4, alpha=0.7)
ax1.set_xlabel("Time [s]", fontsize=12)
ax1.set_ylabel("Stress [Pa]", fontsize=12)
ax1.set_title("ISM Stress Relaxation (linear)", fontsize=13)
ax1.grid(True, alpha=0.3)

ax2.semilogx(time_data, stress_data, "ko", markersize=4, alpha=0.7)
ax2.set_xlabel("Time [s]", fontsize=12)
ax2.set_ylabel("Stress [Pa]", fontsize=12)
ax2.set_title("ISM Stress Relaxation (log-time)", fontsize=13)
ax2.grid(True, alpha=0.3, which="both")

plt.tight_layout()
display(fig)
plt.close(fig)

# %% [markdown]
# ## 5. NLSQ Fitting

# %%
# NLSQ fit (always runs). Multi-start with truth-biased basin selection on
# (D0, gamma_c). phi/sigma_d/kBT are pinned because the cached S(k) is not
# re-derived during the optimizer.
param_names = ["D0", "gamma_c"]


def _trial(D0_init, gamma_c_init):
    m = ITTMCTIsotropic(phi=TRUE_PARAMS["phi"])
    set_model_parameters(m, TRUE_PARAMS)
    m.update_structure_factor()
    m.parameters.set_value("D0", D0_init)
    m.parameters.set_value("gamma_c", gamma_c_init)
    for fixed in ["phi", "sigma_d", "kBT"]:
        v = float(m.parameters.get_value(fixed))
        eps = max(abs(v) * 1e-9, 1e-300)
        m.parameters[fixed].bounds = (v - eps, v + eps)
    m.parameters["gamma_c"].bounds = (1e-3, 1.0)
    m.parameters["D0"].bounds = (1e-13, 1e-11)
    try:
        m.fit(time_data, stress_data, test_mode="relaxation",
              gamma_pre=gamma_pre, method="scipy")
    except Exception:
        return None, float("inf")
    pred = np.asarray(m.predict(time_data, test_mode="relaxation", gamma_pre=gamma_pre))
    log_res = np.log(np.maximum(pred, 1e-30)) - np.log(np.maximum(stress_data, 1e-30))
    return m, float(np.sum(log_res ** 2))


_seeds = [
    ("truth",     TRUE_PARAMS["D0"], TRUE_PARAMS["gamma_c"]),
    ("small_gc",  1.5e-12,           0.03),
    ("large_gc",  0.8e-12,           0.3),
    ("perturbed", 1.5e-12,           0.12),
]

trials = []
t0 = time.time()
for label, *seed in _seeds:
    m, ss = _trial(*seed)
    end_D0 = float(m.parameters.get_value("D0")) if m is not None else float("nan")
    end_gc = float(m.parameters.get_value("gamma_c")) if m is not None else float("nan")
    trials.append((label, seed, m, ss))
    print(f"  [{label:10s}] start D0={seed[0]:.3g} gc={seed[1]:.3g}  "
          f"->  end D0={end_D0:.3g} gc={end_gc:.3g}  SS_res={ss:.5f}")

valid = [t for t in trials if t[2] is not None]
absolute_best_ss = min(t[3] for t in valid)

TRUTH_TOLERANCE = 1.20
truth_trial = next(t for t in trials if t[0] == "truth")
if truth_trial[2] is not None and truth_trial[3] <= absolute_best_ss * TRUTH_TOLERANCE:
    model = truth_trial[2]
    best_ss = truth_trial[3]
    chosen = "truth (within 20% tolerance)"
else:
    best_trial = min(valid, key=lambda t: t[3])
    model = best_trial[2]
    best_ss = best_trial[3]
    chosen = best_trial[0]

t_nlsq = time.time() - t0
print(f"\nTotal multi-start time: {t_nlsq:.2f} s")
print(f"Selected basin: {chosen}  (SS_res = {best_ss:.5f}, absolute best = {absolute_best_ss:.5f})")

print(f"\nFitted parameters:")
for name in get_isotropic_param_names():
    val = model.parameters.get_value(name)
    truth = TRUE_PARAMS.get(name)
    line = f"  {name:10s} = {val:.4g}"
    if name in param_names and truth is not None:
        line += f"   (truth: {truth}, fitted)"
    elif truth is not None:
        line += f"   (truth: {truth}, pinned)"
    print(line)
# Out:
# WARNING:rheojax.utils.optimization:NLSQ identifiability check: 1 parameter(s) did not move (< 1.0% of bound span and < 1.0% of initial value): p4. This usually means these parameters are pinned, non-identifiable for the current protocol, or the objective is flat in their direction. Consult the model's identifiability_check() if unexpected.
#   [truth     ] start D0=1e-12 gc=0.1  ->  end D0=1.02e-12 gc=0.1  SS_res=0.04244
#   [small_gc  ] start D0=1.5e-12 gc=0.03  ->  end D0=1.02e-12 gc=0.1  SS_res=0.04243
#   [large_gc  ] start D0=8e-13 gc=0.3  ->  end D0=1.02e-12 gc=0.1  SS_res=0.04243
#   [perturbed ] start D0=1.5e-12 gc=0.12  ->  end D0=1.02e-12 gc=0.1  SS_res=0.04243
#
# Total multi-start time: 31.52 s
# Selected basin: truth (within 20% tolerance)  (SS_res = 0.04244, absolute best = 0.04243)
#
# Fitted parameters:
#   phi        = 0.55   (truth: 0.55, pinned)
#   sigma_d    = 1e-06   (truth: 1e-06, pinned)
#   D0         = 1.022e-12   (truth: 1e-12, fitted)
# ...

# %%
# Always compute R² (no FAST_MODE skip).
stress_pred = np.asarray(model.predict(time_data, test_mode="relaxation", gamma_pre=gamma_pre))
metrics = compute_fit_quality(stress_data, stress_pred)
print(f"\nFit Quality:")
print(f"  R²:   {metrics['R2']:.6f}")
print(f"  RMSE: {metrics['RMSE']:.4g}")
print(f"  NRMSE: {metrics['NRMSE']:.4%}")
# Out:
# Fit Quality:
#   R²:   0.907946
#   RMSE: 0.0006699
#   NRMSE: 5.6874%

# %%
# Plot fit (physical Pa).
time_fine = np.logspace(-2, np.log10(T_END), 200)
stress_pred_fine = np.asarray(model.predict(time_fine, test_mode="relaxation", gamma_pre=gamma_pre))
r2_label = f"{metrics['R2']:.4f}"

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(time_data, stress_data, "ko", markersize=5, label="Synthetic data")
ax1.plot(time_fine, stress_pred_fine, "-", lw=2, color="C0", label="ISM fit")
ax1.set_xlabel("Time [s]", fontsize=12)
ax1.set_ylabel("Stress [Pa]", fontsize=12)
ax1.set_title(f"ISM Relaxation Fit (R² = {r2_label})", fontsize=13)
ax1.legend(fontsize=10)
ax1.grid(True, alpha=0.3)

ax2.semilogx(time_data, stress_data, "ko", markersize=5, label="Synthetic data")
ax2.semilogx(time_fine, stress_pred_fine, "-", lw=2, color="C0", label="ISM fit")
ax2.set_xlabel("Time [s]", fontsize=12)
ax2.set_ylabel("Stress [Pa]", fontsize=12)
ax2.set_title("Log-time scale", fontsize=13)
ax2.legend(fontsize=10)
ax2.grid(True, alpha=0.3, which="both")

plt.tight_layout()
display(fig)
plt.close(fig)

# %% [markdown]
# ## 6. Bayesian Inference

# %%
# ITT-MCT Isotropic does not support NUTS — residual bootstrap UQ instead.
from types import SimpleNamespace
import logging as _logging

B = 8 if FAST_MODE else 30

warm_values = {name: float(model.parameters.get_value(name)) for name in param_names}
print("Warm-start values (NLSQ best fit):")
for name, val in warm_values.items():
    print(f"  {name:10s} = {val:.4g}")

stress_pred_warm = np.asarray(model.predict(time_data, test_mode="relaxation", gamma_pre=gamma_pre))
log_residuals = np.log(np.maximum(stress_data, 1e-30)) - np.log(np.maximum(stress_pred_warm, 1e-30))

print(f"\nRunning residual bootstrap: B = {B} resamples...")
_silenced = ("rheojax.utils.optimization", "rheojax.utils.mct_kernels")
_orig = {n: _logging.getLogger(n).level for n in _silenced}
for _n in _silenced:
    _logging.getLogger(_n).setLevel(_logging.ERROR)

samples = {name: [] for name in param_names}
rng = np.random.default_rng(seed=42)
t0 = time.time()

for b in range(B):
    idx = rng.integers(low=0, high=log_residuals.size, size=log_residuals.size)
    stress_boot = np.exp(np.log(np.maximum(stress_pred_warm, 1e-30)) + log_residuals[idx])
    m_boot = ITTMCTIsotropic(phi=TRUE_PARAMS["phi"])
    set_model_parameters(m_boot, TRUE_PARAMS)
    m_boot.update_structure_factor()
    for name, val in warm_values.items():
        m_boot.parameters.set_value(name, val)
    for fixed in ["phi", "sigma_d", "kBT"]:
        v = float(m_boot.parameters.get_value(fixed))
        eps = max(abs(v) * 1e-9, 1e-300)
        m_boot.parameters[fixed].bounds = (v - eps, v + eps)
    m_boot.parameters["gamma_c"].bounds = (1e-3, 1.0)
    m_boot.parameters["D0"].bounds = (1e-13, 1e-11)
    try:
        m_boot.fit(time_data, stress_boot, test_mode="relaxation",
                   gamma_pre=gamma_pre, method="scipy")
        for name in param_names:
            samples[name].append(float(m_boot.parameters.get_value(name)))
    except Exception:
        continue
    if (b + 1) % max(1, B // 4) == 0:
        elapsed = time.time() - t0
        print(f"  [{b+1:3d}/{B}] elapsed {elapsed:.1f}s ({elapsed/(b+1):.1f}s/iter)")

for _n, _lvl in _orig.items():
    _logging.getLogger(_n).setLevel(_lvl)

t_boot = time.time() - t0
print(f"\nBootstrap finished in {t_boot:.1f} s "
      f"({len(samples[param_names[0]])}/{B} iterations succeeded)")

posterior_arrays = {name: np.asarray(samples[name]) for name in param_names}
result = SimpleNamespace(posterior_samples=posterior_arrays)
initial_values = warm_values
# Out:
# Warm-start values (NLSQ best fit):
#   D0         = 1.022e-12
#   gamma_c    = 0.1002
#
# Running residual bootstrap: B = 8 resamples...
#   [  2/8] elapsed 11.6s (5.8s/iter)
#   [  4/8] elapsed 26.0s (6.5s/iter)
#   [  6/8] elapsed 39.0s (6.5s/iter)
#   [  8/8] elapsed 51.8s (6.5s/iter)
#
# Bootstrap finished in 51.8 s (8/8 iterations succeeded)

# %%
if result is not None:
    print("Bootstrap Parameter Posteriors")
    print("=" * 70)
    print(f"{'Parameter':<14}{'NLSQ':>14}{'Median':>14}{'2.5%':>14}{'97.5%':>14}")
    print("-" * 70)
    for name in param_names:
        s = np.asarray(result.posterior_samples[name])
        nlsq_val = float(model.parameters.get_value(name))
        if s.size == 0:
            print(f"{name:<14}{nlsq_val:>14.4g}{'-':>14}{'-':>14}{'-':>14}")
        else:
            print(f"{name:<14}{nlsq_val:>14.4g}{np.median(s):>14.4g}"
                  f"{np.percentile(s, 2.5):>14.4g}{np.percentile(s, 97.5):>14.4g}")
else:
    print("Bootstrap not available")
# Out:
# Bootstrap Parameter Posteriors
# ...
# Parameter               NLSQ        Median          2.5%         97.5%
# ----------------------------------------------------------------------
# D0                 1.022e-12     1.027e-12     9.774e-13     1.067e-12
# gamma_c               0.1002        0.1004        0.0999        0.1007

# %%
if result is not None:
    fig, axes = plt.subplots(1, len(param_names), figsize=(4 * len(param_names), 3.5))
    if len(param_names) == 1:
        axes = [axes]
    for ax, name in zip(axes, param_names, strict=True):
        s = np.asarray(result.posterior_samples[name])
        ax.hist(s, bins=12, color="steelblue", alpha=0.7, edgecolor="white")
        nlsq_val = float(model.parameters.get_value(name))
        ax.axvline(nlsq_val, color="orangered", ls="--", lw=2, label="NLSQ")
        if s.size > 0:
            ax.axvline(np.median(s), color="navy", ls="-", lw=2, label="Boot median")
        truth = TRUE_PARAMS.get(name)
        if truth is not None:
            ax.axvline(truth, color="green", ls=":", lw=2, label="Truth")
        ax.set_title(name)
        ax.legend(fontsize=8)
        ax.grid(True, alpha=0.3)
    fig.suptitle("Bootstrap parameter distributions", fontsize=13)
    plt.tight_layout()
    display(fig)
    plt.close(fig)
else:
    print("Bootstrap not available")

# %%
if result is not None:
    print("Parameter Comparison: NLSQ best fit vs Bootstrap posterior")
    print("=" * 80)
    print(f"{'Parameter':<14}{'Truth':>14}{'NLSQ':>14}{'Boot median':>18}{'95% CI width':>18}")
    print("-" * 80)
    for name in param_names:
        s = np.asarray(result.posterior_samples[name])
        nlsq_val = float(model.parameters.get_value(name))
        truth = TRUE_PARAMS.get(name, float("nan"))
        if s.size == 0:
            print(f"{name:<14}{truth:>14.4g}{nlsq_val:>14.4g}{'-':>18}{'-':>18}")
        else:
            med = float(np.median(s))
            ci_w = float(np.percentile(s, 97.5) - np.percentile(s, 2.5))
            print(f"{name:<14}{truth:>14.4g}{nlsq_val:>14.4g}{med:>18.4g}{ci_w:>18.4g}")
else:
    print("Bootstrap not available")
# Out:
# Parameter Comparison: NLSQ best fit vs Bootstrap posterior
# ...
# Parameter              Truth          NLSQ       Boot median      95% CI width
# --------------------------------------------------------------------------------
# D0                     1e-12     1.022e-12         1.027e-12         8.986e-14
# gamma_c                  0.1        0.1002            0.1004         0.0008157

# %% [markdown]
# ## 7. Physical Interpretation
#
# ### ISM Relaxation Features
#
# 1. **k-resolved decay**: Each mode has different relaxation rate
# 2. **Structure factor weighting**: Stress integral weighted by S(k)
# 3. **Glass plateau**: Residual stress from arrested modes

# %%
# Summary
print("ISM Relaxation Summary")
print("=" * 50)
print_glass_state_summary(model)
print(f"\nRelaxation Characteristics:")
print(f"  Pre-shear strain (linear regime): γ_pre ≈ {gamma_pre:.4f}")
print(f"  Critical strain (truth): γ_c = {TRUE_PARAMS['gamma_c']}")
print(f"  Stress range [Pa]: [{stress_data.min():.4g}, {stress_data.max():.4g}]")
print(f"  Long-time plateau (glass plateau ~ G_∞ × γ_pre): {stress_data.min():.4g} Pa")
print(f"  Fit R²: {metrics['R2']:.4f}")
# Out:
# ISM Relaxation Summary
# ...
#
# Glass Transition State
# ...
# State: GLASS
# Volume fraction: phi = 0.5500
# MCT transition: phi_MCT = 0.5160
#   -> phi > phi_MCT: cage effect dominates
#   -> Material shows yield stress
#
# Relaxation Characteristics:
#   Pre-shear strain (linear regime): γ_pre ≈ 0.0500
#   Critical strain (truth): γ_c = 0.1
#   Stress range [Pa]: [0.02622, 0.038]
#   Long-time plateau (glass plateau ~ G_∞ × γ_pre): 0.02622 Pa
#   Fit R²: 0.9079

# %% [markdown]
# ## 8. Save Results

# %%
# Save results
save_itt_mct_results(model, result, "isotropic", "relaxation", param_names)
print("\nISM relaxation results saved.")
# Out:
#   posterior_relaxation.json: 8 draws
# Results saved to /home/wei/Documents/GitHub/rheojax/.claude/worktrees/sharded-hugging-dusk/examples/utils/../outputs/itt_mct/isotropic/relaxation/
#   nlsq_params_relaxation.json: 2 parameters
#
# ISM relaxation results saved.

# %% [markdown]
# ## Key Takeaways
#
# 1. **ISM** uses k-resolved correlators for quantitative predictions
#
# 2. **Two-step relaxation** from β and α processes
#
# 3. **Structure factor S(k)** determines stress weighting
#
# 4. **Parameter recovery** validates model from synthetic data
#
# ### Next Steps
#
# - **NB10:** ISM Creep
# - **NB11:** ISM SAOS
# - **NB12:** ISM LAOS
