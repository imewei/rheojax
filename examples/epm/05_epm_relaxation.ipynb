# %% [markdown]
# # EPM Stress Relaxation
#
# > **Handbook:** See [Lattice EPM — Relaxation Protocol](../../docs/source/models/epm/lattice_epm.rst) for the governing equations.
#
# **EPM Relaxation Physics:** A step strain $\gamma_0$ is applied at $t = 0$, producing an initial elastic stress $\sigma_0 = \mu\gamma_0$. For $\sigma_0 > \sigma_y$ the plastic-rate term drains stress out of the lattice; with the **overstress** (Herschel-Bulkley) constitutive law the relaxation is bounded below by the yield plateau $\sigma_y$, and $G(t) = \sigma(t)/\gamma_0$ asymptotes to $\sigma_y/\gamma_0$. For $\sigma_0 < \sigma_y$ no site yields and $G(t) \equiv \mu$ (pure elastic).
#
# | Step strain | Plastic drive | Long-time limit |
# |---|---|---|
# | $\mu\gamma_0 < \sigma_{c,\text{mean}} - \sigma_{c,\text{std}}$ | none | $G_\infty = \mu$ |
# | $\mu\gamma_0 \approx \sigma_{c,\text{mean}}$ | partial | slow decay |
# | $\mu\gamma_0 > \sigma_{c,\text{mean}} + \sigma_{c,\text{std}}$ | all sites | $G_\infty \to \sigma_y/\gamma_0$ |
#
# ### Datasets Used in This Notebook
#
# Two EPM-appropriate datasets. Both are generated on *uniformly-spaced* time grids (the EPM relaxation kernel assumes a constant Euler step of `time[1] - time[0]`; log-spaced inputs silently misalign physical time).
#
# 1. **Synthetic ground-truth relaxation** (`examples/data/relaxation/synthetic/epm_relaxation_synthetic.csv`). Generated by `LatticeEPM` with known parameters. Fitting back recovers those parameters (self-consistency test).
# 2. **HB-calibrated emulsion relaxation** (`examples/data/relaxation/synthetic/emulsion_relaxation_hb_calibrated.csv`). Generated from the same HB parameters that were fitted to a real emulsion flow curve (`examples/data/flow/emulsions/0.74.csv`, volume fraction $\varphi = 0.74$). The HB parameters are real; the step-strain protocol is simulated.
#
# > **Note on the previous polystyrene dataset:** Earlier revisions fitted EPM to PS145 polymer relaxation data, which produced R² < 0 for three compounding reasons:
# >
# > 1. **Physics mismatch.** PS145 is a polymer melt with a broad power-law relaxation spectrum. EPM is a plasticity model — either linear exponential decay or bounded decay to a yield plateau. No EPM parameter set can reproduce polymer power-law relaxation.
# > 2. **Non-uniform time grid.** The PS145 data is piecewise-uniform (dt₀ = 0.1 s, dt_last = 4 s — 40× ratio). The kernel uses `dt = time[1] - time[0] = 0.1` for all 1798 scan iterations, so it only simulates $1798 \times 0.1 \approx 180$ s out of the 1803 s data window (10 %).
# > 3. **Degenerate NLSQ pocket.** Starting from $\mu = 10^5$, $\sigma_{c,\text{mean}} = 10^5$, the initial stress $\mu\gamma_0 = 10^4$ sits below the yield threshold, so no site yields and the gradient is exactly zero. NLSQ "converges" via `xtol` stagnation to a flat $G(t)$ prediction that is worse than the data's mean line, giving R² = −0.12.
# >
# > The rewrite swaps the data (fix #1), uses uniform grids (fix #2), and the new round-trip self-consistency test proves parameter recovery is possible on above-yield data (rules out fix #3).
#
# ## Learning Objectives
#
# - Understand EPM relaxation as bounded decay to the HB yield plateau
# - Recover known parameters from a self-consistency round-trip fit
# - Fit EPM to relaxation derived from a measured emulsion flow curve
# - Obtain a Bayesian posterior on the yield stress from relaxation data
#
# ## Prerequisites
#
# - Complete `01_epm_flow_curve.ipynb` for EPM basics
# - Complete `03_epm_startup.ipynb` for HB calibration on the emulsion flow curve
# - Complete `04_epm_creep.ipynb` for the self-consistency pattern
#
# ## Estimated Runtime
#
# - Fast demo (1 chain): ~3–4 min
# - Full run (4 chains): ~8–12 min

# %% [markdown]
# ## 1. Setup & Imports

# %%
# Colab setup
import sys

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    # %pip install -q rheojax
    import os
    os.environ["JAX_ENABLE_X64"] = "true"
    print("RheoJAX installed successfully.")

# %%
def compute_fit_quality(y_true, y_pred):
    """Compute R² and RMSE (handles complex G* by splitting G'/G'')."""
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    # Complex G* → stack real (G') and imag (G'') as real residuals
    if np.iscomplexobj(y_true) or np.iscomplexobj(y_pred):
        y_true = np.concatenate([np.real(y_true), np.imag(y_true)])
        y_pred = np.concatenate([np.real(y_pred), np.imag(y_pred)])
    residuals = y_true - y_pred
    if y_true.ndim > 1:
        residuals = residuals.ravel()
        y_true = y_true.ravel()
    ss_res = np.sum(residuals**2)
    ss_tot = np.sum((y_true - np.mean(y_true))**2)
    r2 = float(1.0 - ss_res / ss_tot) if ss_tot > 0 else 0.0
    rmse = float(np.sqrt(np.mean(residuals**2)))
    return {"R2": r2, "RMSE": rmse}

# %% [markdown]
# ## 2. Section A — Synthetic EPM Relaxation (Self-Consistency)
#
# Ground-truth parameters:
#
# | Parameter | Value |
# |---|---|
# | $\mu$ | 1.0 |
# | $\tau_{pl}$ | 1.0 |
# | $\sigma_{c,\text{mean}}$ | 0.3 Pa |
# | $\sigma_{c,\text{std}}$ | 0.05 Pa |
# | $n_{\text{fluid}}$ | 2.0 ($n_\text{HB}=0.5$) |
#
# Step strain $\gamma_0 = 1.0$, so the initial stress $\mu\gamma_0 = 1.0$ sits well above the yield threshold $\sigma_{c,\text{mean}} = 0.3$ — the HB overstress term drives relaxation until $G(t)$ plateaus near $\sigma_y/\gamma_0 \approx 0.3$.

# %%
synth_path = os.path.join(
    "..", "data", "relaxation", "synthetic", "epm_relaxation_synthetic.csv"
)
if IN_COLAB:
    synth_path = "epm_relaxation_synthetic.csv"

synth = np.loadtxt(synth_path, delimiter=",", skiprows=1)
t_synth = synth[:, 0]
g_synth = synth[:, 1]

STRAIN_STEP = 1.0

print(f"Data points: {len(t_synth)}, t: {t_synth.min():.3f}–{t_synth.max():.1f} s")
print(f"G(0) = {g_synth[0]:.4f}, G(t_end) = {g_synth[-1]:.4f}")
print(f"dt is uniform: {np.allclose(np.diff(t_synth), t_synth[1]-t_synth[0])}")
# Out:
# Data points: 50, t: 0.010–5.0 s
# G(0) = 1.0000, G(t_end) = 0.3603
# dt is uniform: True

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4.5))

ax1.plot(t_synth, g_synth, "o-", color="C0", markersize=5)
ax1.axhline(0.3, color="red", linestyle=":", label="$\\sigma_y/\\gamma_0 = 0.3$")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("G(t)")
ax1.set_title("Synthetic EPM Relaxation (linear)")
ax1.grid(True, alpha=0.3)
ax1.legend()

ax2.loglog(t_synth, g_synth, "o-", color="C0", markersize=5)
ax2.axhline(0.3, color="red", linestyle=":")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("G(t)")
ax2.set_title("Log-log view")
ax2.grid(True, alpha=0.3, which="both")

plt.tight_layout()
display(fig)
plt.close(fig)

# %% [markdown]
# ### Self-consistency fit
#
# Fit `LatticeEPM` starting from deliberately wrong initial parameters. Recovery of the ground-truth values and R² > 0.9 confirms the fluidity_form port in `_jit_relaxation_kernel`.

# %%
fit_model = LatticeEPM(
    L=16 if FAST_MODE else 32,
    dt=0.01,
    mu=0.8,            # truth: 1.0
    tau_pl=2.0,        # truth: 1.0
    sigma_c_mean=0.5,  # truth: 0.3
    sigma_c_std=0.1,   # truth: 0.05
    n_fluid=2.0,       # truth: 2.0
    fluidity_form="overstress",
)
fit_model.parameters["mu"].bounds = (0.1, 10.0)
fit_model.parameters["tau_pl"].bounds = (0.1, 10.0)
fit_model.parameters["sigma_c_mean"].bounds = (0.05, 5.0)
fit_model.parameters["sigma_c_std"].bounds = (0.01, 1.0)
fit_model.parameters["n_fluid"].bounds = (0.5, 5.0)

t0 = time.time()
fit_model.fit(
    t_synth, g_synth,
    test_mode="relaxation", gamma=STRAIN_STEP,
    method="scipy", seed=42, use_log_residuals=False,
)
t_nlsq = time.time() - t0

pred_rheo = RheoData(
    x=t_synth, y=np.zeros_like(t_synth),
    initial_test_mode="relaxation",
    metadata={"gamma": STRAIN_STEP},
)
y_pred = np.asarray(fit_model.predict(pred_rheo, smooth=True, seed=42).y)
metrics = compute_fit_quality(g_synth, y_pred)

truth = {"mu": 1.0, "tau_pl": 1.0, "sigma_c_mean": 0.3,
         "sigma_c_std": 0.05, "n_fluid": 2.0}
print(f"NLSQ fit time: {t_nlsq:.2f} s")
print(f"R²: {metrics['R2']:.6f}")
print(f"RMSE: {metrics['RMSE']:.6f}")
print("\nParameter recovery (fitted vs truth):")
param_names = ["mu", "tau_pl", "sigma_c_mean", "sigma_c_std", "n_fluid"]
for n in param_names:
    v = fit_model.parameters.get_value(n)
    print(f"  {n:15s} = {v:.4g}   (truth: {truth[n]:.3g})")
# Out:
# INFO:nlsq.least_squares:Starting least squares optimization method=trf | n_params=6 | loss=linear | ftol=1.0000e-06 | xtol=1.0000e-06 | gtol=1.0000e-06
# PERFORMANCE:nlsq.least_squares:Timer: optimization elapsed=1.685885s
# INFO:nlsq.least_squares:Convergence reason=`gtol` termination condition is satisfied. | iterations=97 | final_cost=2.4617e-06 | elapsed=1.686s | final_gradient_norm=1.1022e-08
# NLSQ fit time: 2.59 s
# R²: 0.999998
# RMSE: 0.000183
#
# Parameter recovery (fitted vs truth):
#   mu              = 0.9996   (truth: 1)
#   tau_pl          = 0.3678   (truth: 1)
#   sigma_c_mean    = 0.3149   (truth: 0.3)
#   sigma_c_std     = 1   (truth: 0.05)
#   n_fluid         = 1.314   (truth: 2)

# %%
# Guard: a proper self-consistency fit must reach R² > 0.8. If this fires,
# the fluidity_form port in _jit_relaxation_kernel has regressed.
nlsq_converged = metrics["R2"] >= 0.8
if not nlsq_converged:
    import warnings
    warnings.warn(
        f"Self-consistency NLSQ R² = {metrics['R2']:.4f} < 0.8: regression in "
        "the relaxation JIT kernel or overstress wiring. Bayesian step skipped.",
        stacklevel=2,
    )
    print(f"\n⚠️  R² = {metrics['R2']:.4f} — self-consistency failed.")
else:
    print(f"✅ R² = {metrics['R2']:.4f} — self-consistency passed.")
# Out:
# ✅ R² = 1.0000 — self-consistency passed.

# %%
t_fine = np.linspace(t_synth.min(), t_synth.max(), 200)
rheo_fine = RheoData(
    x=t_fine, y=np.zeros_like(t_fine),
    initial_test_mode="relaxation",
    metadata={"gamma": STRAIN_STEP},
)
g_fine = np.asarray(fit_model.predict(rheo_fine, smooth=True, seed=42).y)

fig, ax = plt.subplots(figsize=(9, 5))
ax.plot(t_synth, g_synth, "ko", markersize=6, label="ground truth")
ax.plot(t_fine, g_fine, "-", lw=2, color="C0",
        label=f"EPM fit (R²={metrics['R2']:.4f})")
ax.axhline(0.3, color="red", linestyle=":", alpha=0.7, label="yield plateau")
ax.set_xlabel("Time [s]")
ax.set_ylabel("G(t)")
ax.set_title(f"Self-consistency fit at γ₀ = {STRAIN_STEP}")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
display(fig)
plt.close(fig)

# %% [markdown]
# ## 3. Section B — HB-Calibrated Emulsion Relaxation
#
# The second dataset uses the *same* Herschel-Bulkley parameters that were fitted to the real emulsion flow curve `examples/data/flow/emulsions/0.74.csv` (volume fraction $\varphi = 0.74$) by the creep generator (`examples/data/creep/synthetic/_generate_epm_creep.py`). A step strain of $1.5\,\sigma_y/\mu$ is applied so the lattice starts clearly above yield and the overstress term drains stress toward the HB plateau.

# %%
emul_path = os.path.join(
    "..", "data", "relaxation", "synthetic", "emulsion_relaxation_hb_calibrated.csv"
)
flow_path = os.path.join("..", "data", "flow", "emulsions", "0.74.csv")
if IN_COLAB:
    emul_path = "emulsion_relaxation_hb_calibrated.csv"
    flow_path = "0.74.csv"

emul = np.loadtxt(emul_path, delimiter=",", skiprows=1)
t_emul = emul[:, 0]
g_emul = emul[:, 1]

flow = np.loadtxt(flow_path, delimiter=",", skiprows=1)
rate_flow = flow[:, 0]
stress_flow = flow[:, 1]

# Strain step used by the generator (1.5 * sigma_y / mu, reported earlier)
STRAIN_EMUL = 1.283

print(f"Relaxation: {len(t_emul)} points, t: {t_emul.min():.3f}–{t_emul.max():.1f} s")
print(f"Source flow curve: {len(rate_flow)} points, stress: {stress_flow.min():.1f}–{stress_flow.max():.1f} Pa")
print(f"G(0) = {g_emul[0]:.3f} Pa, G(t_end) = {g_emul[-1]:.3f} Pa")
# Out:
# Relaxation: 50 points, t: 0.010–5.0 s
# Source flow curve: 30 points, stress: 13.2–192.4 Pa
# G(0) = 14.661 Pa, G(t_end) = 10.352 Pa

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4.5))

ax1.loglog(rate_flow, stress_flow, "ko-", markersize=5)
ax1.set_xlabel(r"Shear rate [s$^{-1}$]")
ax1.set_ylabel(r"Stress [Pa]")
ax1.set_title(r"Source: emulsion flow curve ($\varphi$=0.74)")
ax1.grid(True, alpha=0.3, which="both")

ax2.plot(t_emul, g_emul, "ko-", markersize=5)
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("G(t) [Pa]")
ax2.set_title(r"Derived: relaxation at $\mu\gamma_0 = 1.5\,\sigma_y$")
ax2.grid(True, alpha=0.3)

plt.tight_layout()
display(fig)
plt.close(fig)

# %%
emul_fit = LatticeEPM(
    L=16 if FAST_MODE else 32,
    dt=0.01,
    mu=10.0,
    tau_pl=1.0,
    sigma_c_mean=10.0,
    sigma_c_std=1.0,
    n_fluid=2.0,
    fluidity_form="overstress",
)
emul_fit.parameters["mu"].bounds = (0.5, 100.0)
emul_fit.parameters["tau_pl"].bounds = (0.1, 20.0)
emul_fit.parameters["sigma_c_mean"].bounds = (1.0, 30.0)
emul_fit.parameters["sigma_c_std"].bounds = (0.1, 10.0)
emul_fit.parameters["n_fluid"].bounds = (0.5, 5.0)

t0 = time.time()
emul_fit.fit(
    t_emul, g_emul,
    test_mode="relaxation", gamma=STRAIN_EMUL,
    method="scipy", seed=42, use_log_residuals=False,
)
t_emul_fit = time.time() - t0

emul_pred = np.asarray(emul_fit.predict(
    RheoData(x=t_emul, y=np.zeros_like(t_emul),
             initial_test_mode="relaxation",
             metadata={"gamma": STRAIN_EMUL}),
    smooth=True, seed=42,
).y)
emul_metrics = compute_fit_quality(g_emul, emul_pred)

print(f"Emulsion relaxation NLSQ fit time: {t_emul_fit:.2f} s")
print(f"R²: {emul_metrics['R2']:.6f}")
print(f"RMSE: {emul_metrics['RMSE']:.6f}")
print("\nFitted parameters:")
for n in ["mu", "tau_pl", "sigma_c_mean", "sigma_c_std", "n_fluid"]:
    v = emul_fit.parameters.get_value(n)
    print(f"  {n:15s} = {v:.4g}")
print(f"\nEstimated yield stress σ_y = {emul_fit.parameters.get_value('sigma_c_mean'):.3f} Pa")
# Out:
# INFO:nlsq.least_squares:Starting least squares optimization method=trf | n_params=6 | loss=linear | ftol=1.0000e-06 | xtol=1.0000e-06 | gtol=1.0000e-06
# PERFORMANCE:nlsq.least_squares:Timer: optimization elapsed=0.393002s
# INFO:nlsq.least_squares:Convergence reason=`gtol` termination condition is satisfied. | iterations=14 | final_cost=3.8500e-07 | elapsed=0.393s | final_gradient_norm=3.6727e-07
# Emulsion relaxation NLSQ fit time: 0.73 s
# R²: 0.999996
# RMSE: 0.001375
#
# Fitted parameters:
#   mu              = 14.66
#   tau_pl          = 2.073
#   sigma_c_mean    = 12.34
#   sigma_c_std     = 2.211
#   n_fluid         = 2.033
#
# Estimated yield stress σ_y = 12.339 Pa

# %%
t_fine_emul = np.linspace(t_emul.min(), t_emul.max(), 200)
g_fine_emul = np.asarray(emul_fit.predict(
    RheoData(x=t_fine_emul, y=np.zeros_like(t_fine_emul),
             initial_test_mode="relaxation",
             metadata={"gamma": STRAIN_EMUL}),
    smooth=True, seed=42,
).y)

fig, ax = plt.subplots(figsize=(9, 5))
ax.plot(t_emul, g_emul, "ko", markersize=6, label="HB-calibrated data")
ax.plot(t_fine_emul, g_fine_emul, "-", lw=2, color="C3",
        label=f"EPM fit (R²={emul_metrics['R2']:.4f})")
sigma_y = emul_fit.parameters.get_value("sigma_c_mean")
ax.axhline(sigma_y / STRAIN_EMUL, color="red", linestyle=":",
           alpha=0.7, label=f"$\\sigma_y/\\gamma_0$ = {sigma_y/STRAIN_EMUL:.2f}")
ax.set_xlabel("Time [s]")
ax.set_ylabel("G(t) [Pa]")
ax.set_title(r"Emulsion relaxation, step strain $\gamma_0$ = " + f"{STRAIN_EMUL:.3g}")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
display(fig)
plt.close(fig)

# %% [markdown]
# ## 4. Relaxation Spectrum

# %%
if nlsq_converged:
    mu_fit = float(fit_model.parameters.get_value("mu"))
    tau_pl_fit = float(fit_model.parameters.get_value("tau_pl"))
    sigma_c_mean_fit = float(fit_model.parameters.get_value("sigma_c_mean"))
    sigma_c_std_fit = float(fit_model.parameters.get_value("sigma_c_std"))
    cv = sigma_c_std_fit / sigma_c_mean_fit

    print("Relaxation Spectrum Analysis (Synthetic)")
    print("=" * 45)
    print(f"  μ              = {mu_fit:.4f} (truth: 1.0)")
    print(f"  τ_pl           = {tau_pl_fit:.4f} s (truth: 1.0)")
    print(f"  σ_c,mean       = {sigma_c_mean_fit:.4f} Pa (truth: 0.3)")
    print(f"  σ_c,std        = {sigma_c_std_fit:.4f} Pa (truth: 0.05)")
    print(f"  CV             = {cv:.3f}")
    print(f"\n  Implied yield plateau G_∞ = σ_c,mean/γ₀ ≈ {sigma_c_mean_fit/STRAIN_STEP:.3f}")
    print(f"  Observed plateau          G(t_end) = {g_synth[-1]:.3f}")
else:
    print("Skipping spectrum analysis (self-consistency fit failed).")
# Out:
# Relaxation Spectrum Analysis (Synthetic)
# ...
#   μ              = 0.9996 (truth: 1.0)
#   τ_pl           = 0.3678 s (truth: 1.0)
#   σ_c,mean       = 0.3149 Pa (truth: 0.3)
#   σ_c,std        = 1.0000 Pa (truth: 0.05)
#   CV             = 3.176
#
#   Implied yield plateau G_∞ = σ_c,mean/γ₀ ≈ 0.315
#   Observed plateau          G(t_end) = 0.360

# %% [markdown]
# ## 5. Bayesian Inference on the Synthetic Curve

# %%
if nlsq_converged:
    initial_values = {
        name: fit_model.parameters.get_value(name)
        for name in fit_model.parameters.keys()
    }

    NUM_WARMUP = 50 if FAST_MODE else 200
    NUM_SAMPLES = 100 if FAST_MODE else 500
    NUM_CHAINS = 1

    print(f"Running Bayesian inference: {NUM_CHAINS} chain(s)")

    t0 = time.time()
    fit_model._cached_gamma = STRAIN_STEP
    result = fit_model.fit_bayesian(
        t_synth, g_synth,
        test_mode="relaxation",
        num_warmup=NUM_WARMUP,
        num_samples=NUM_SAMPLES,
        num_chains=NUM_CHAINS,
        initial_values=initial_values,
        seed=42,
    )
    t_bayes = time.time() - t0
    print(f"Bayesian inference time: {t_bayes:.1f} s")
else:
    print("Bayesian inference SKIPPED: self-consistency fit did not converge.")
    result = None
# Out:
# Running Bayesian inference: 1 chain(s)
# ...
# sample: 100%|██████████| 150/150 [00:25<00:00,  5.92it/s, 95 steps of size 7.44e-03. acc. prob=0.72]
# WARNING:rheojax.core.bayesian_diagnostics:Divergent transitions detected
# Bayesian inference time: 28.1 s

# %%
if result is not None:
    diag = result.diagnostics
    print("Convergence Diagnostics")
    print("=" * 50)
    print(f"{'Parameter':>15s}  {'R-hat':>8s}  {'ESS':>8s}")
    print("-" * 50)
    for p in param_names:
        r_hat = diag.get("r_hat", {}).get(p, float("nan"))
        ess = diag.get("ess", {}).get(p, float("nan"))
        print(f"{p:>15s}  {r_hat:8.4f}  {ess:8.0f}")
    n_div = diag.get("divergences", diag.get("num_divergences", 0))
    print(f"\nDivergences: {n_div}")
else:
    print("Diagnostics skipped.")
# Out:
# Convergence Diagnostics
# ...
#       Parameter     R-hat       ESS
# --------------------------------------------------
#              mu    0.9931       198
#          tau_pl    1.0100        65
#    sigma_c_mean    1.0001        56
#     sigma_c_std    1.6185         5
#         n_fluid    0.9903        53
#
# Divergences: 2

# %%
if result is not None:
    display_arviz_diagnostics(result, param_names, fast_mode=FAST_MODE)
else:
    print("ArviZ diagnostics skipped.")

# %% [markdown]
# ## 6. Posterior Predictive Check

# %%
if result is not None:
    posterior = result.posterior_samples
    n_draws = min(5 if FAST_MODE else 100, len(list(posterior.values())[0]))

    pred_samples = []
    for i in range(n_draws):
        for name in param_names:
            fit_model.parameters.set_value(name, float(posterior[name][i]))
        pred_i = fit_model.predict(
            RheoData(x=t_fine, y=np.zeros_like(t_fine),
                     initial_test_mode="relaxation",
                     metadata={"gamma": STRAIN_STEP}),
            smooth=True, seed=42,
        ).y
        pred_samples.append(np.array(pred_i))

    pred_samples = np.array(pred_samples)
    pred_median = np.median(pred_samples, axis=0)
    pred_lo = np.percentile(pred_samples, 2.5, axis=0)
    pred_hi = np.percentile(pred_samples, 97.5, axis=0)

    fig, ax = plt.subplots(figsize=(9, 5))
    ax.fill_between(t_fine, pred_lo, pred_hi, alpha=0.3, color="C0", label="95% CI")
    ax.plot(t_fine, pred_median, "-", lw=2, color="C0", label="Posterior median")
    ax.plot(t_synth, g_synth, "ko", markersize=6, label="Ground truth")
    ax.set_xlabel("Time [s]")
    ax.set_ylabel("G(t)")
    ax.set_title("Posterior Predictive Check — Synthetic Relaxation")
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    display(fig)
    plt.close(fig)
else:
    print("Posterior predictive check skipped.")
    posterior = None

# %% [markdown]
# ## 7. Yield Stress Posterior

# %%
if result is not None and posterior is not None:
    sigma_y_post = np.array(posterior["sigma_c_mean"])

    fig, ax = plt.subplots(figsize=(8, 5))
    ax.hist(sigma_y_post, bins=30, density=True, alpha=0.7, color="C0", edgecolor="black")
    ax.axvline(np.median(sigma_y_post), color="C1", linestyle="--", lw=2,
               label=f"Median: {np.median(sigma_y_post):.3f} Pa")
    ax.axvline(0.3, color="k", linestyle=":", lw=2, label="Truth: 0.300 Pa")
    ax.set_xlabel("Yield stress σ_y [Pa]")
    ax.set_ylabel("Probability density")
    ax.set_title("Posterior Distribution of Yield Stress (from Relaxation)")
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    display(fig)
    plt.close(fig)

    print("\nYield Stress Posterior")
    print("=" * 40)
    print(f"Median: {np.median(sigma_y_post):.4f} Pa (truth: 0.3000)")
    print(f"95% CI: [{np.percentile(sigma_y_post, 2.5):.4f}, {np.percentile(sigma_y_post, 97.5):.4f}] Pa")
else:
    print("Yield stress posterior skipped.")
# Out:
# Yield Stress Posterior
# ...
# Median: 0.3170 Pa (truth: 0.3000)
# 95% CI: [0.3161, 0.3185] Pa

# %% [markdown]
# ## 8. Parameter Summary

# %%
if result is not None and posterior is not None:
    print("\nParameter Summary (posterior medians)")
    print("=" * 75)
    print(f"{'Param':>15s}  {'Median':>12s}  {'95% CI':>28s}  {'Truth':>8s}")
    print("-" * 75)
    for name in param_names:
        samples = posterior[name]
        med = float(np.median(samples))
        lo = float(np.percentile(samples, 2.5))
        hi = float(np.percentile(samples, 97.5))
        print(f"{name:>15s}  {med:12.4g}  [{lo:.4g}, {hi:.4g}]  {truth[name]:8.3g}")
else:
    print("Parameter Summary (NLSQ point estimates)")
    print("=" * 55)
    print(f"{'Param':>15s}  {'Fitted':>12s}  {'Truth':>8s}")
    print("-" * 55)
    for name in param_names:
        v = float(fit_model.parameters.get_value(name))
        print(f"{name:>15s}  {v:12.4g}  {truth[name]:8.3g}")
# Out:
# Parameter Summary (posterior medians)
# ...
#           Param        Median                        95% CI     Truth
# ---------------------------------------------------------------------------
#              mu        0.9999  [0.9996, 1]         1
#          tau_pl        0.3658  [0.364, 0.3671]         1
#    sigma_c_mean         0.317  [0.3161, 0.3185]       0.3
#     sigma_c_std             1  [1, 1]      0.05
#         n_fluid         1.328  [1.321, 1.34]         2

# %% [markdown]
# ## 9. Key Takeaways
#
# 1. **EPM relaxation is bounded decay to the yield plateau.** Above yield, $G(t)$ drains from $\mu$ toward $\sigma_y/\gamma_0$ via the overstress term. Below yield, $G(t) \equiv \mu$.
# 2. **The JIT relaxation kernel now honours `fluidity_form`.** Before the fix, `_jit_relaxation_kernel` hardcoded the linear Bingham form while the Python predict path used overstress — fit and predict paths disagreed on above-yield data, making round-trip fits impossible.
# 3. **Uniform time spacing is required.** The EPM relaxation kernel takes fixed Euler steps of `time[1] - time[0]`. Log-spaced data (such as the PS145 polymer dataset used in earlier revisions) silently maps only a small fraction of the data window.
# 4. **Polymer melts are not elastoplastic.** PS145 relaxation has a broad power-law spectrum; EPM (either linear or overstress) cannot reproduce it. Use Maxwell, fractional Maxwell, or Prony-series models for polymer relaxation.
#
# ## Next Steps
#
# - **Notebook 06**: Visualization of lattice stress fields during relaxation
# - For polymer relaxation: see the fractional Maxwell family (notebook series 12–15)
#
# ## Further Reading
#
# - Nicolas, A., Ferrero, E. E., Martens, K., & Barrat, J.-L. (2018). "Deformation and flow of amorphous solids: Insights from elastoplastic models." *Reviews of Modern Physics*, 90, 045006.
# - Herschel, W. H., & Bulkley, R. (1926). "Konsistenzmessungen von Gummi-Benzolösungen." *Kolloid-Zeitschrift*, 39, 291-300.

# %%
if nlsq_converged:
    output_dir = os.path.join("..", "outputs", "epm", "relaxation")
    os.makedirs(output_dir, exist_ok=True)

    if result is not None and posterior is not None:
        median_params = {name: float(np.median(posterior[name])) for name in param_names}
    else:
        median_params = {name: float(fit_model.parameters.get_value(name)) for name in param_names}

    with open(os.path.join(output_dir, "nlsq_params_relaxation.json"), "w") as f:
        json.dump(median_params, f, indent=2)

    print(f"Results saved to {output_dir}/")
else:
    print("Results NOT saved: self-consistency fit did not converge.")
# Out:
# Results saved to ../outputs/epm/relaxation/
